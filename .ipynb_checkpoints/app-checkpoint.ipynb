# %%
# Import Dependencies
import pandas as pd
import numpy as np
import requests
from requests.exceptions import ConnectionError
from bs4 import BeautifulSoup
import os
import time
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.neural_network import MLPClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.svm import SVC
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.colors import LinearSegmentedColormap

# %%
def get_team_stats_data(year: int) -> pd.DataFrame:
    # Pause for 3.5 seconds to avoid getting blocked (20 requests/minute limit)
    time.sleep(3.5)

    # Set the URL for season standings page
    url = f'https://www.basketball-reference.com/leagues/NBA_{year}.html'

    # Get the HTML content of the page
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')

    # Get Columns to Use for each table
    columns_params = {
        'rate_stats': ['Team', 'G', 'MP', 'FG', 'FGA', 'FG%', '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'FT', 'FTA', 'FT%', 'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS'],
        'advanced_stats': ['Team', 'Age', 'W', 'L', 'PW', 'PL', 'MOV', 'SOS', 'SRS', 'ORtg', 'DRtg', 'NRtg', 'Pace', 'FTr', '3PAr', 'TS%', 'Team eFG%', 'Team TOV%', 'Team ORB%', 'Team FT/FGA', 'Opponent eFG%', 'Opponent TOV%', 'Opponent DRB%', 'Opponent FT/FGA', 'Arena', 'Attend.', 'Attend./G'],
        'team_shooting_stats': ['Team', 'G', 'MP', 'FG%', 'Dist.', '%FGA 2P', '%FGA 0-3', '%FGA 3-10', '%FGA 10-16', '%FGA 16-3P', '%FGA 3P', '2P%', '0-3%', '3-10%', '10-16%', '16-3P%', '3P%', '2P Assisted %', '3P Assisted %', '%FGA Dunks', 'MD% Dunks', '%FGA Layup', 'MD% Layups', '%3PA Corner', '3P% Corner', 'Heaves Att.', 'Heaves Made'],
        'opponent_shooting_stats': ['Team', 'G', 'MP', 'FG%', 'Dist.', '%FGA 2P', '%FGA 0-3', '%FGA 3-10', '%FGA 10-16', '%FGA 16-3P', '%FGA 3P', '2P%', '0-3%', '3-10%', '10-16%', '16-3P%', '3P%', '2P Assisted %', '3P Assisted %', '%FGA Dunks', 'MD% Dunks', '%FGA Layup', 'MD% Layups', '%3PA Corner', '3P% Corner'],
        'team_shooting_stats_pre_2002': ['Team', 'G', 'MP', 'FG%', 'Dist.', '%FGA 2P', '%FGA 0-3', '%FGA 3-10', '%FGA 10-16', '%FGA 16-3P', '%FGA 3P', '2P%', '0-3%', '3-10%', '10-16%', '16-3P%', '3P%', '2P Assisted %', '3P Assisted %', '%FGA Dunks', 'MD% Dunks', '%3PA Corner', '3P% Corner', 'Heaves Att.', 'Heaves Made'],
        'opponent_shooting_stats_pre_2002': ['Team', 'G', 'MP', 'FG%', 'Dist.', '%FGA 2P', '%FGA 0-3', '%FGA 3-10', '%FGA 10-16', '%FGA 16-3P', '%FGA 3P', '2P%', '0-3%', '3-10%', '10-16%', '16-3P%', '3P%', '2P Assisted %', '3P Assisted %', '%FGA Dunks', 'MD% Dunks', '%3PA Corner', '3P% Corner']
    }

    # Get Standings Data & Combine dataframes & Clean the Team name column
    eastern_conference_standings_df = get_standings_data(soup, year, 'Eastern')
    western_conference_standings_df = get_standings_data(soup, year, 'Western')
    league_standings_df = pd.concat([eastern_conference_standings_df, western_conference_standings_df], ignore_index=True)
    league_standings_df = league_standings_df.sort_values(by='W/L%', ascending=False).reset_index(drop=True)
    
    # Get Team & Opponent Stats Data (Rate, Shooting, and Advanced Stats)
    team_rate_stats_df = get_team_stats(soup, year, 'team', 'per_poss-team', 'rate', columns_params['rate_stats'])
    team_advanced_stats_df = get_team_stats(soup, year, 'team', 'advanced-team', 'advanced', columns_params['advanced_stats'])
    opponent_rate_stats_df = get_team_stats(soup, year, 'opponent', 'per_poss-opponent', 'rate', columns_params['rate_stats'])
    if year >= 1997:
        if year < 2002:
            team_shooting_stats_df = get_team_stats(soup, year, 'team', 'shooting-team', 'shooting', columns_params['team_shooting_stats_pre_2002'])
            opponent_shooting_stats_df = get_team_stats(soup, year, 'opponent', 'shooting-opponent', 'shooting', columns_params['opponent_shooting_stats_pre_2002'])
        else:
            team_shooting_stats_df = get_team_stats(soup, year, 'team', 'shooting-team', 'shooting', columns_params['team_shooting_stats'])
            opponent_shooting_stats_df = get_team_stats(soup, year, 'opponent', 'shooting-opponent', 'shooting', columns_params['opponent_shooting_stats'])

    # Drop unnecessary columns from the dataframes
    team_advanced_stats_df = team_advanced_stats_df.drop(columns=['W', 'L', 'SRS'])
    opponent_rate_stats_df = opponent_rate_stats_df.drop(columns=['G', 'MP', 'Team/Opponent'])
    if year >= 1997:
        team_shooting_stats_df = team_shooting_stats_df.drop(columns=['G', 'MP', 'FG%', 'Team/Opponent'])
        opponent_shooting_stats_df = opponent_shooting_stats_df.drop(columns=['G', 'MP', 'FG%', 'Team/Opponent'])

    # Clean the Team name column for each dataframe
    if year >= 1997:
        league_standings_df, team_rate_stats_df, team_shooting_stats_df, team_advanced_stats_df, opponent_rate_stats_df, opponent_shooting_stats_df = clean_team_name_column([league_standings_df, team_rate_stats_df, team_shooting_stats_df, team_advanced_stats_df, opponent_rate_stats_df, opponent_shooting_stats_df])
    else:
        league_standings_df, team_rate_stats_df, team_advanced_stats_df, opponent_rate_stats_df = clean_team_name_column([league_standings_df, team_rate_stats_df, team_advanced_stats_df, opponent_rate_stats_df])
    
    # Add custom suffixes to all column names that would otherwise be duplicated
    if year >= 1997:
        team_rate_stats_df, team_shooting_stats_df, team_advanced_stats_df, opponent_rate_stats_df, opponent_shooting_stats_df = add_suffix([team_rate_stats_df, team_shooting_stats_df, team_advanced_stats_df, opponent_rate_stats_df, opponent_shooting_stats_df], ['_Per100_Team', '_Shooting', '_Advanced', '_Per100_Opponent', '_Shooting_Opponent'])
    else:
        team_rate_stats_df, team_advanced_stats_df, opponent_rate_stats_df = add_suffix([team_rate_stats_df, team_advanced_stats_df, opponent_rate_stats_df], ['_Per100_Team', '_Advanced', '_Per100_Opponent'])

    # Merge the dataframes
    df = pd.merge(league_standings_df, team_rate_stats_df, on=['Team', 'Year'])
    df = pd.merge(df, team_advanced_stats_df, on=['Team', 'Year'])
    df = pd.merge(df, opponent_rate_stats_df, on=['Team', 'Year'])
    if year >= 1997:
        df = pd.merge(df, team_shooting_stats_df, on=['Team', 'Year'])
        df = pd.merge(df, opponent_shooting_stats_df, on=['Team', 'Year'])
    
    # Get the playoff odds data
    odds_df = get_odds_data(year - 1, year)

    # Merge the odds data with the main dataframe
    df = pd.merge(df, odds_df, on='Team', how='left')

    return df

# %%
def get_game_logs_data(year: int, team_abbreviations: dict) -> pd.DataFrame:
    inverted_team_abbreviations = {v: k for k, v in team_abbreviations.items()}
    df_regular_season_combined = pd.DataFrame()
    df_playoffs_combined = pd.DataFrame()
    years_without_start_time_columns = ['G', 'Date', 'Box Score Link', 'Home/Road', 'Opponent', 'Result', 'OT', 'Tm', 'Opp', 'W', 'L', 'Streak',' Attend.', 'LOG', 'Notes']
    years_with_start_time_columns = ['G', 'Date', 'Start (ET)', 'Box Score Link', 'Home/Road', 'Opponent', 'Result', 'OT', 'Tm', 'Opp', 'W', 'L', 'Streak',' Attend.', 'LOG', 'Notes']

    for abbreviation in team_abbreviations.values():
        # Pause for 3.5 seconds to avoid getting blocked (20 requests/minute limit)
        time.sleep(3.5)

        print(f'Getting game logs for {abbreviation} in {year}')

        # Set the URL for the season game logs page
        url = f'https://www.basketball-reference.com/teams/{abbreviation}/{year}_games.html'

        # Get the HTML content of the page
        response = requests.get(url)
        if response.status_code == 404:
            print(f'Page not found for {abbreviation} in {year}. Skipping...')
            continue
        soup = BeautifulSoup(response.content, 'html.parser')

        # Find the table with the game logs data
        table = soup.find('table', {'id': 'games'})
        rows = table.find_all('tr')
        data = []

        # Extract the data from the table
        for row in rows:
            cols = row.find_all('td')
            cols = [ele.text.strip() for ele in cols]
            data.append(cols)

        if len(data[1]) == 15:
            df_regular_season = pd.DataFrame(data, columns=years_without_start_time_columns)
        else:
            df_regular_season = pd.DataFrame(data, columns=years_with_start_time_columns)
        df_regular_season = df_regular_season.dropna(subset=['G'])

        # Add the Team/Year to the dataframe
        df_regular_season['Team'] = inverted_team_abbreviations[abbreviation]
        df_regular_season['Year'] = year

        # Find the table with the playoff game logs data (if it exists)
        table = soup.find('table', {'id': 'games_playoffs'})
        if table is not None:
            rows = table.find_all('tr')
            data = []

            # Extract the data from the table
            for row in rows:
                cols = row.find_all('td')
                cols = [ele.text.strip() for ele in cols]
                data.append(cols)

            if len(data[1]) == 15:
                df_playoffs = pd.DataFrame(data, columns=years_without_start_time_columns)
            else:
                df_playoffs = pd.DataFrame(data, columns=years_with_start_time_columns)
            df_playoffs = df_playoffs.dropna(subset=['G'])

            # Add the Team/Year to the dataframe
            df_playoffs['Team'] = inverted_team_abbreviations[abbreviation]
            df_playoffs['Year'] = year

            # Combine the dataframes for each team
            df_regular_season_combined = pd.concat([df_regular_season_combined, df_regular_season], ignore_index=True)
            df_playoffs_combined = pd.concat([df_playoffs_combined, df_playoffs], ignore_index=True)

    return df_regular_season_combined, df_playoffs_combined

# %%
def get_standings_data(soup: BeautifulSoup, year: int, conference: str) -> pd.DataFrame:
    # Find the standings table for the appropriate conference
    table_id = 'divs_standings_E' if conference == 'Eastern' else 'divs_standings_W'
    table = soup.find('table', {'id': table_id})
    rows = table.find_all('tr')
    data = []

    # Extract the data from the table
    for row in rows:
        team = row.find('th').text.strip()
        if 'Division' not in team and 'Conference' not in team:
            cols = row.find_all('td')
            cols = [ele.text.strip() for ele in cols]
            data.append([team] + cols)
    df = pd.DataFrame(data, columns=['Team', 'W', 'L', 'W/L%', 'GB', 'PS/G', 'PA/G', 'SRS'])
    df['Year'] = year
    df['Conference'] = 'Eastern' if conference == 'Eastern' else 'Western'
    df['Made Playoffs'] = df['Team'].apply(lambda x: 1 if '*' in x else 0)
    
    return df

# %%
def get_team_stats(soup: BeautifulSoup, year: int, team_or_opponent: str, table_id: str, table_type: str, columns: list) -> pd.DataFrame:
    # Find the appropriate table
    table = soup.find('table', {'id': table_id})
    rows = table.find_all('tr')
    data = []

    # Extract the data from the table
    for row in rows:
        rank = row.find('th').text.strip()
        if rank == 'Rk' or rank == '':
            continue
        cols = row.find_all('td')
        cols = [ele.text.strip() for ele in cols if ele.text.strip() != '']
        data.append(cols)
    df = pd.DataFrame(data, columns=columns)
    df['Year'] = year
    if table_type != 'advanced':
        df['Team/Opponent'] = 'Team' if team_or_opponent == 'team' else 'Opponent'
    
    return df

# %%
def get_odds_data_html(url, retries=3, backoff_factor=0.5):
    for attempt in range(retries):
        try:
            response = requests.get(url)
            response.raise_for_status()  # Raises an HTTPError if the response status code is 4XX or 5XX
            return response
        except ConnectionError as e:
            print(f"Connection failed: {e}. Retrying...")
            time.sleep(backoff_factor * (2 ** attempt))
        except requests.exceptions.HTTPError as e:
            print(f"HTTP Error: {e}")
            break
    return None

# %%
def get_odds_data(start_year: int, end_year: int) -> pd.DataFrame:
    url = f'https://www.sportsoddshistory.com/nba-main/?y={start_year}-{end_year}&sa=nba&a=finals&o=r1'

    # Get the HTML content of the page
    response = get_odds_data_html(url)
    if response:
        soup = BeautifulSoup(response.content, 'html.parser')

        # Find the table with the odds data
        table = soup.find('table', {'class': 'soh1'})

        # Extract the data from the table
        data = []

        # Find the index of the "Round 1" column
        headers = table.find_all('th')
        round_1_index = None
        counter = 0
        for i, header in enumerate(headers):
            counter += 1
            if '...' in header.text:
                counter -= 1
            if 'Round 1' in header.text:
                round_1_index = counter - len([th for th in headers[:i] if th.has_attr('rowspan')])  # Adjust for rowspan
                break

        # Add the data to the list if the column was found
        if round_1_index is not None:
            for row in table.find_all('tbody')[0].find_all('tr'):
                cols = row.find_all('td')
                team_name = cols[0].text.strip()
                round_1_data = cols[round_1_index].text.strip()
                data.append((team_name, round_1_data))
        else:
            print("Pre-Playoff odds not found.")

        # Create a dataframe from the data
        df = pd.DataFrame(data, columns=['Team', 'Odds'])

        return df

# %%
def add_suffix(dfs: list[pd.DataFrame], suffix: list[str]) -> list[pd.DataFrame]:
    current_index = 0

    for df in dfs:
        for column in df.columns:
            if column not in ['Team', 'Year', 'G', 'MP', 'Team/Opponent']:
                dfs[current_index] = dfs[current_index].rename(columns={column: column + suffix[current_index]})
        current_index += 1

    return dfs

# %%
def clean_team_name_column(dfs: list[pd.DataFrame]) -> list[pd.DataFrame]:
    for df in dfs:
        df['Team'] = (df['Team'].str.replace(r'\(\d+\)', '', regex=True)
                                .str.replace('(', '')
                                .str.replace(')', '')
                                .str.replace('*', '')
                                .str.rstrip())
    return dfs

# %%
def fill_in_custom_feature_columns(df: pd.DataFrame, df_game_log_regular_season: pd.DataFrame, df_game_log_playoffs: pd.DataFrame, year: int, start_year: int) -> pd.DataFrame:
    if 'Record vs .600+ Teams' not in df.columns:
        df['Record vs .600+ Teams'] = 0.0
    if 'Number of Playoff Wins (Last Year)' not in df.columns:
        df['Number of Playoff Wins (Last Year)'] = 0
        df['Champion Share (Last Year)'] = 0.0

    # Ensure numerical columns hold numeric values
    df['W/L%'] = pd.to_numeric(df['W/L%'], errors='coerce')
    df_game_log_regular_season['Tm'] = pd.to_numeric(df_game_log_regular_season['Tm'], errors='coerce')
    df_game_log_regular_season['Opp'] = pd.to_numeric(df_game_log_regular_season['Opp'], errors='coerce')

    # Calculate the record vs .600+ teams (in the regular season)
    teams_600_plus = df[(df['W/L%'] >= 0.600) & (df['Year'] == year)]['Team'].values
    for team in df['Team'].unique():
        # Filter game logs for current team & year against .600+ teams
        team_games_vs_600_plus = df_game_log_regular_season[(df_game_log_regular_season['Team'] == team) & 
                                                            (df_game_log_regular_season['Opponent'].isin(teams_600_plus)) & 
                                                            (df_game_log_regular_season['Year'] == year)]

        # Calculate win rate
        if not team_games_vs_600_plus.empty:
            wins = team_games_vs_600_plus['Result'].value_counts().get('W', 0)
            total_games = len(team_games_vs_600_plus)
            win_rate = wins / total_games if total_games > 0 else 0.0
        else:
            win_rate = 0.0
        
        # Assign win rate to the team in df
        df.loc[(df['Team'] == team) & (df['Year'] == year), 'Record vs .600+ Teams'] = win_rate
    
    # Calculate Record in Clutch Games (in the regular season)
    df_game_log_regular_season['Is Clutch'] = abs(df_game_log_regular_season['Tm'] - df_game_log_regular_season['Opp']) <= 5
    df_game_log_regular_season['Clutch Win'] = (df_game_log_regular_season['Is Clutch']) & (df_game_log_regular_season['Tm'] > df_game_log_regular_season['Opp'])

    # Create copies of Year/Team columns to avoid deprecated groupby behavior
    df['Year Copy'] = df['Year']
    df['Team Copy'] = df['Team']
    df_game_log_regular_season['Year Copy'] = df_game_log_regular_season['Year']
    df_game_log_regular_season['Team Copy'] = df_game_log_regular_season['Team']
    clutch_win_rates = df_game_log_regular_season.groupby(['Team Copy', 'Year Copy']).apply(lambda x: x['Clutch Win'].sum() / x['Is Clutch'].sum() if x['Is Clutch'].sum() > 0 else 0.0, include_groups=False).reset_index(name='Record in Clutch Games')
    df = df.merge(clutch_win_rates, on=['Team Copy', 'Year Copy'], how='left', suffixes=('', '_current'))
    
    # Handle Duplicate Columns (if they exist)
    if 'Record in Clutch Games_current' in df.columns:
        df['Record in Clutch Games'] = df.apply(lambda row: row['Record in Clutch Games_current'] if pd.notnull(row['Record in Clutch Games_current']) else row['Record in Clutch Games'], axis=1)
    
    # Drop unnecessary columns
    df_game_log_regular_season.drop(columns=['Is Clutch', 'Clutch Win'], inplace=True)
    df.drop(columns=['Year Copy', 'Team Copy'], inplace=True)
    if 'Record in Clutch Games_current' in df.columns:
        df.drop(columns=['Record in Clutch Games_current'], inplace=True)
    
    
    # Calculate Number of Playoff Wins in the previous year
    if year > start_year:
        for team in df['Team'].unique():
            previous_year_df = df_game_log_playoffs[(df_game_log_playoffs['Year'] == year - 1) & (df_game_log_playoffs['Team'] == team)]
            if not previous_year_df.empty:
                playoff_wins = previous_year_df['Result'].value_counts().get('W', 0)
            else:
                playoff_wins = 0

            # Calculate Champion Share
            playoff_wins_required = 0
            if year - 1 > 2002: # 2003 onwards had 16 playoff wins required
                playoff_wins_required = 16
            elif year - 1 > 1983: # 1984 had 15 playoff wins required
                playoff_wins_required = 15
            else:
                playoff_wins_required = 12 # Only 12 playoff wins required since 1980
            champion_share = playoff_wins / playoff_wins_required
            df.loc[(df['Team'] == team) & (df['Year'] == year), 'Number of Playoff Wins (Last Year)'] = playoff_wins
            df.loc[(df['Team'] == team) & (df['Year'] == year), 'Champion Share (Last Year)'] = champion_share

    return df

# %%
def scrape_and_save_data(df: pd.DataFrame, start_year: int, end_year: int) -> pd.DataFrame:
    team_info = {
    "Atlanta Hawks": {"abbreviation": "ATL", "start_year": 1980, "end_year": "Current"},
    "Boston Celtics": {"abbreviation": "BOS", "start_year": 1980, "end_year": "Current"},
    "Brooklyn Nets": {"abbreviation": "BRK", "start_year": 2013, "end_year": "Current"},
    "Charlotte Bobcats": {"abbreviation": "CHA", "start_year": 2005, "end_year": 2014},
    "Charlotte Hornets": {"abbreviation": "CHH", "start_year": 1989, "end_year": 2002}, # Returns to CHA in 2015 with abbreviation CHO
    "Chicago Bulls": {"abbreviation": "CHI", "start_year": 1980, "end_year": "Current"},
    "Cleveland Cavaliers": {"abbreviation": "CLE", "start_year": 1980, "end_year": "Current"},
    "Dallas Mavericks": {"abbreviation": "DAL", "start_year": 1981, "end_year": "Current"},
    "Denver Nuggets": {"abbreviation": "DEN", "start_year": 1980, "end_year": "Current"},
    "Detroit Pistons": {"abbreviation": "DET", "start_year": 1980, "end_year": "Current"},
    "Golden State Warriors": {"abbreviation": "GSW", "start_year": 1980, "end_year": "Current"},
    "Houston Rockets": {"abbreviation": "HOU", "start_year": 1980, "end_year": "Current"},
    "Indiana Pacers": {"abbreviation": "IND", "start_year": 1980, "end_year": "Current"},
    "Kansas City Kings": {"abbreviation": "KCK", "start_year": 1980, "end_year": 1985},
    "Los Angeles Clippers": {"abbreviation": "LAC", "start_year": 1985, "end_year": "Current"},
    "Los Angeles Lakers": {"abbreviation": "LAL", "start_year": 1980, "end_year": "Current"},
    "Memphis Grizzlies": {"abbreviation": "MEM", "start_year": 2002, "end_year": "Current"},
    "Miami Heat": {"abbreviation": "MIA", "start_year": 1989, "end_year": "Current"},
    "Milwaukee Bucks": {"abbreviation": "MIL", "start_year": 1980, "end_year": "Current"},
    "Minnesota Timberwolves": {"abbreviation": "MIN", "start_year": 1990, "end_year": "Current"},
    "New Jersey Nets": {"abbreviation": "NJN", "start_year": 1980, "end_year": 2012},
    "New Orleans Hornets": {"abbreviation": "NOH", "start_year": 2003, "end_year": 2013}, # Abbreviation is NOK in 2006 & 2007
    "New Orleans Pelicans": {"abbreviation": "NOP", "start_year": 2014, "end_year": "Current"},
    "New York Knicks": {"abbreviation": "NYK", "start_year": 1980, "end_year": "Current"},
    "Oklahoma City Thunder": {"abbreviation": "OKC", "start_year": 2009, "end_year": "Current"},
    "Orlando Magic": {"abbreviation": "ORL", "start_year": 1990, "end_year": "Current"},
    "Philadelphia 76ers": {"abbreviation": "PHI", "start_year": 1980, "end_year": "Current"},
    "Phoenix Suns": {"abbreviation": "PHO", "start_year": 1980, "end_year": "Current"},
    "Portland Trail Blazers": {"abbreviation": "POR", "start_year": 1980, "end_year": "Current"},
    "Sacramento Kings": {"abbreviation": "SAC", "start_year": 1986, "end_year": "Current"},
    "San Antonio Spurs": {"abbreviation": "SAS", "start_year": 1980, "end_year": "Current"},
    "San Diego Clippers": {"abbreviation": "SDC", "start_year": 1980, "end_year": 1984},
    "Seattle SuperSonics": {"abbreviation": "SEA", "start_year": 1980, "end_year": 2008},
    "Toronto Raptors": {"abbreviation": "TOR", "start_year": 1996, "end_year": "Current"},
    "Utah Jazz": {"abbreviation": "UTA", "start_year": 1980, "end_year": "Current"},
    "Vancouver Grizzlies": {"abbreviation": "VAN", "start_year": 1996, "end_year": 2001},
    "Washington Bullets": {"abbreviation": "WSB", "start_year": 1980, "end_year": 1997},
    "Washington Wizards": {"abbreviation": "WAS", "start_year": 1998, "end_year": "Current"}
    }
    df_game_logs_regular_season_combined = pd.DataFrame()
    df_game_logs_playoffs_combined = pd.DataFrame()

    # Scrape data for each year (if no Excel file exists in folder, pausing to avoid getting blocked [20 requests/minute limit])
    for year in range(start_year, end_year):
        print(f'Getting data for {year}')

        # Get Team Abbreviations
        team_abbreviations = {team: data['abbreviation'] for team, data in team_info.items() if (data['start_year'] <= year and (data['end_year'] == 'Current' or data['end_year'] >= year))}
        if year == 2006 or year == 2007:
            team_abbreviations['New Orleans Hornets'] = 'NOK'
        if year >= 2015:
            team_abbreviations['Charlotte Hornets'] = 'CHO'
        
        # Get Team Data
        df = pd.concat([df, get_team_stats_data(year)])

        # Get Game Logs Data (when available)
        df_game_logs_regular_season, df_game_logs_playoffs = get_game_logs_data(year, team_abbreviations)

        # Combine the dataframes for each year
        df_game_logs_regular_season_combined = pd.concat([df_game_logs_regular_season_combined, df_game_logs_regular_season], ignore_index=True)
        df_game_logs_playoffs_combined = pd.concat([df_game_logs_playoffs_combined, df_game_logs_playoffs], ignore_index=True)

        # Filter Regular Season Game Logs for calculated features
        df = fill_in_custom_feature_columns(df, df_game_logs_regular_season_combined, df_game_logs_playoffs_combined, year, start_year)

    # Save to Excel
    df.to_excel('NBA_Team_Stats.xlsx', index=False)

    return df

# %%
def prepare_data_for_ml(df: pd.DataFrame, championship_teams: dict) -> pd.DataFrame:
    # Drop unnecessary rows/columns
    columns_to_drop = ['Conference', 'G', 'MP', 'W', 'L', 'GB', 'PS/G', 'PA/G', 'Team/Opponent', 'Heaves Att._Shooting', 'Heaves Made_Shooting', 'Arena_Advanced', 'Attend._Advanced', 'Attend./G_Advanced', 'FG%_Per100_Team', 'FG%_Per100_Opponent', 'PW_Advanced', 'PL_Advanced', 'MOV_Advanced', 'SOS_Advanced', 'Age_Advanced', 'Pace_Advanced']
    df = df.drop(columns=[col for col in columns_to_drop if col in df.columns])
    df = df[df.columns.drop(list(df.filter(regex='_Shooting|3P%|2P%|FT%|_Per100')))]

    # Scale the data
    df['Year Copy'] = df['Year']
    df = df.groupby('Year Copy').apply(scale_group, include_groups=False)

    # Eliminate non-playoff teams
    df = df[df['Made Playoffs'] == 1]
    df = df.drop(columns=['Made Playoffs'])

    # Find Implied Probabilities from Odds
    df['Implied Odds'] = df['Odds'].apply(odds_to_probability)
    df = df.drop(columns=['Odds'])

    # Fill in missing values (missing odds data from sportsoddshistory for some teams in 1983, 1987, and 1990)
    df = df.fillna(0)

    # Add a column for the target variable (Won Championship)
    # Won Championship = 1 if team won the championship that year, 0 otherwise
    df['Won Championship'] = 0
    for year, team in championship_teams.items():
        df.loc[(df['Year'] == year) & (df['Team'] == team), 'Won Championship'] = 1

    return df

# %%
def scale_group(group):
    scaler = MinMaxScaler(feature_range=(0, 1))
    columns_to_scale = ['ORtg_Advanced', 'DRtg_Advanced', 'NRtg_Advanced', 'FTr_Advanced', '3PAr_Advanced', 'TS%_Advanced', 'Team eFG%_Advanced', 'Team TOV%_Advanced', 'Team ORB%_Advanced', 'Team FT/FGA_Advanced', 'Opponent eFG%_Advanced', 'Opponent TOV%_Advanced', 'Opponent DRB%_Advanced', 'Opponent FT/FGA_Advanced']
    columns_to_invert = ['DRtg_Advanced', 'Team TOV%_Advanced', 'Opponent eFG%_Advanced', 'Opponent DRB%_Advanced', 'Opponent FT/FGA_Advanced']

    # Scale columns
    group[columns_to_scale] = scaler.fit_transform(group[columns_to_scale])
    
    # Invert scaling for specified columns where lower values are better
    for column in columns_to_invert:
        group[column] = 1 - group[column]
    
    return group

# %%
def odds_to_probability(odds: str) -> float:
    if odds > 0:
        probability = 100 / (odds + 100)
    else:
        probability = (-odds) / ((-odds) + 100)
    
    return probability

# %%
def get_train_test_data(df: pd.DataFrame, test_year: int) -> tuple[pd.DataFrame, pd.DataFrame, pd.DataFrame, pd.DataFrame, pd.DataFrame, pd.DataFrame]:
    # Split the data into training and testing sets
    train_df = df[df['Year'] < test_year]
    test_df = df[df['Year'] == test_year]

    X_train = train_df.drop(columns=['Team', 'Year', 'Won Championship'])
    y_train = train_df['Won Championship']
    X_test = test_df.drop(columns=['Team', 'Year', 'Won Championship'])
    y_test = test_df['Won Championship']

    return train_df, test_df, X_train, y_train, X_test, y_test

# %%
def train_model(df: pd.DataFrame, test_year: int, model_type: str) -> tuple[str, bool]:
    train_df, test_df, X_train, y_train, X_test, y_test = get_train_test_data(df, test_year)

    # Select and create the model based on model_type
    if model_type == 'logistic_regression':
        model = LogisticRegression(max_iter=10000, random_state=42)
    elif model_type == 'random_forest':
        model = RandomForestClassifier(random_state=42)
    elif model_type == 'svm':
        model = SVC(probability=True, random_state=42)
    elif model_type == 'gradient_boosting':
        model = GradientBoostingClassifier(random_state=42)
    elif model_type == 'knn':
        model = KNeighborsClassifier(n_neighbors=5)
    elif model_type == 'decision_tree':
        model = DecisionTreeClassifier(random_state=42)
    elif model_type == 'neural_network':
        model = MLPClassifier(hidden_layer_sizes=(100,), max_iter=10000, activation='tanh', random_state=42)
    elif model_type == 'naive_bayes':
        model = GaussianNB()
    elif model_type == 'ada_boost':
        model = AdaBoostClassifier(algorithm='SAMME', random_state=42)
    else:
        raise ValueError("Invalid model type. Choose a different model.")

    # Train the model
    model.fit(X_train, y_train)
    y_pred_proba = model.predict_proba(X_test)[:, 1]

    # Get the predicted_champion & top 5 contenders
    max_proba_index = np.argmax(y_pred_proba)
    predicted_champion = test_df.iloc[max_proba_index]['Team']
    top_contenders = test_df['Team'].values[np.argsort(y_pred_proba)[::-1]][:5]
    top_contenders_probabilities = np.sort(y_pred_proba)[::-1][:5]
    predicted_contenders = {team: probability for team, probability in zip(top_contenders, top_contenders_probabilities)}

    # Check if the prediction was correct
    actual_champion = test_df.loc[y_test == 1, 'Team'].values[0]
    prediction_correct = actual_champion == predicted_champion

    return predicted_champion, prediction_correct, predicted_contenders

# %%
def print_results(results):
    for model in range(len(results)):
        for year, result in results[model].items():
            print(f"Year: {year}, Predicted Champion: {result['Predicted Champion']}, Prediction Correct: {result['Prediction Correct']}, Contenders: {result['Contenders']}")

        correct_predictions = sum([result['Prediction Correct'] for result in results[model].values()])
        total_predictions = len(results[model])
        accuracy = correct_predictions / total_predictions
        last_year = max(results[model].keys())
        print(f"Model Accuracy: {accuracy} ({correct_predictions}/{total_predictions}) [{results[model][last_year]['Name']}]")
        print("\n")

# %%
def display_heatmap(results_df: pd.DataFrame):
    # Set up the matplotlib figure
    plt.figure(figsize=(10, 8))

    # Draw the heatmap with the custom colormap (red = 0, green = 1)
    colors = ["red", "green"]
    n_bins = 2
    cmap = LinearSegmentedColormap.from_list("custom_binary", colors, N=n_bins)
    sns.heatmap(results_df, annot=True, cmap=cmap, cbar=False, fmt="d")

    # Add labels and title
    plt.title('Model Prediction Accuracy Over Years')
    plt.xlabel('Year')
    plt.ylabel('Model')

    # Show the plot
    plt.show()

# %%
def display_stacked_bar_chart(results_df: pd.DataFrame, start_year: int, end_year: int):
    # Stacked bar chart showing number of models that predicted the correct champion each year
    correct_predictions_by_year = {}
    incorrect_predictions_by_year = {}
    for year in range(start_year + 1, end_year):
        correct_predictions_by_year[year] = results_df.loc[:, year].sum()
        incorrect_predictions_by_year[year] = len(results_df) - correct_predictions_by_year[year]

    # Plot the stacked bar chart
    fig, ax = plt.subplots()
    ax.bar(correct_predictions_by_year.keys(), correct_predictions_by_year.values(), label='Correct Predictions', color='green')
    ax.bar(incorrect_predictions_by_year.keys(), incorrect_predictions_by_year.values(), bottom=list(correct_predictions_by_year.values()), label='Incorrect Predictions', color='red')
    ax.set_xlabel('Year')
    ax.set_ylabel('Number of Models')
    ax.set_title('Number of Models with Correct and Incorrect Predictions by Year')
    ax.legend()
    plt.show()

# %%
def display_cumulative_accuracy_line_chart(results_df: pd.DataFrame):
    # Calculate cumulative accuracy for each model over the years
    cumulative_accuracy = results_df.cumsum(axis=1) / np.arange(1, results_df.shape[1] + 1)

    # Plot the cumulative accuracy line chart
    plt.figure(figsize=(10, 8))
    for model in cumulative_accuracy.index:
        plt.plot(cumulative_accuracy.columns, cumulative_accuracy.loc[model], label=model)

    plt.xlabel('Year')
    plt.ylabel('Cumulative Accuracy')
    plt.title('Cumulative Accuracy of Models Over Time')
    plt.legend(loc='best')
    plt.grid(True)
    plt.show()

# %%
def display_model_score_by_year(results_df: pd.DataFrame, model_results: list, start_year: int, end_year: int, championship_teams: dict):
    # Initialize model_scores with model names and set initial scores to 0
    model_scores = {model[start_year + 1]['Name']: 0 for model in model_results}

    # Calculate the model score for each year
    for year in range(start_year + 1, end_year):
        for model in model_results:
            model_name = model[start_year + 1]['Name']
            champion_team = championship_teams[year]
            if champion_team == model[year]['Predicted Champion']:
                model_scores[model_name] += 1.0 # Full credit for predicting the champion, regardless of probability as that is the goal of the model
            elif champion_team in model[year]['Contenders']:
                probability_of_champion = model[year]['Contenders'][champion_team]
                model_scores[model_name] += probability_of_champion # Adjusts score based on the probability of victory
            else:
                model_scores[model_name] += 0.0 # No credit given if the champion is not in the top 5 contenders


    # Plot the model scores
    plt.figure(figsize=(18, 8))
    plt.bar(model_scores.keys(), model_scores.values())
    plt.xlabel('Model')
    plt.ylabel('Model Score')
    plt.title('Model Scores')
    plt.show()

# %%
def main():
    # Set the start and end years
    start_year = 1980
    end_year = 2025

    # Get the championship teams for each year
    championship_teams = {
        1980: 'Los Angeles Lakers',
        1981: 'Boston Celtics',
        1982: 'Los Angeles Lakers',
        1983: 'Philadelphia 76ers',
        1984: 'Boston Celtics',
        1985: 'Los Angeles Lakers',
        1986: 'Boston Celtics',
        1987: 'Los Angeles Lakers',
        1988: 'Los Angeles Lakers',
        1989: 'Detroit Pistons',
        1990: 'Detroit Pistons',
        1991: 'Chicago Bulls',
        1992: 'Chicago Bulls',
        1993: 'Chicago Bulls',
        1994: 'Houston Rockets',
        1995: 'Houston Rockets',
        1996: 'Chicago Bulls',
        1997: 'Chicago Bulls',
        1998: 'Chicago Bulls',
        1999: 'San Antonio Spurs',
        2000: 'Los Angeles Lakers',
        2001: 'Los Angeles Lakers',
        2002: 'Los Angeles Lakers',
        2003: 'San Antonio Spurs',
        2004: 'Detroit Pistons',
        2005: 'San Antonio Spurs',
        2006: 'Miami Heat',
        2007: 'San Antonio Spurs',
        2008: 'Boston Celtics',
        2009: 'Los Angeles Lakers',
        2010: 'Los Angeles Lakers',
        2011: 'Dallas Mavericks',
        2012: 'Miami Heat',
        2013: 'Miami Heat',
        2014: 'San Antonio Spurs',
        2015: 'Golden State Warriors',
        2016: 'Cleveland Cavaliers',
        2017: 'Golden State Warriors',
        2018: 'Golden State Warriors',
        2019: 'Toronto Raptors',
        2020: 'Los Angeles Lakers',
        2021: 'Milwaukee Bucks',
        2022: 'Golden State Warriors',
        2023: 'Denver Nuggets',
        2024: 'Boston Celtics'
    }

    # Create a dataframe
    df = pd.DataFrame()

    # Load data from file if it exists, else scrape & save data from basketball-reference then load it
    file_exists = True if os.path.isfile('NBA_Team_Stats.xlsx') else False
    if file_exists == False:
        df = scrape_and_save_data(df, start_year, end_year)
    df = pd.read_excel('NBA_Team_Stats.xlsx')

    # Prep df for machine learning
    df = prepare_data_for_ml(df, championship_teams)

    # Save the prepped data to a new Excel file (if needed)
    prepped_file_exists = True if os.path.isfile('NBA_Team_Stats_Prepped.xlsx') else False
    if prepped_file_exists == False:
        df.to_excel('NBA_Team_Stats_Prepped.xlsx', index=False)

    # Train Models
    LR_results = {}
    RF_results = {}
    SVM_results = {}
    GB_results = {}
    KNN_results = {}
    DT_results = {}
    NN_results = {}
    NB_results = {}
    ADA_results = {}
    for year in range(start_year + 1, end_year):
        print(f'Training models for {year}')
        LR_champion, LR_prediction_correct, LR_contenders = train_model(df, year, 'logistic_regression')
        RF_champion, RF_prediction_correct, RF_contenders = train_model(df, year, 'random_forest')
        SVM_champion, SVM_prediction_correct, SVM_contenders = train_model(df, year, 'svm')
        GB_champion, GB_prediction_correct, GB_contenders = train_model(df, year, 'gradient_boosting')
        KNN_champion, KNN_prediction_correct, KNN_contenders = train_model(df, year, 'knn')
        DT_champion, DT_prediction_correct, DT_contenders = train_model(df, year, 'decision_tree')
        NN_champion, NN_prediction_correct, NN_contenders = train_model(df, year, 'neural_network')
        NB_champion, NB_prediction_correct, NB_contenders = train_model(df, year, 'naive_bayes')
        ADA_champion, ADA_prediction_correct, ADA_contenders = train_model(df, year, 'ada_boost')
        
        LR_results[year] = {'Predicted Champion': LR_champion, 'Prediction Correct': LR_prediction_correct, 'Contenders': LR_contenders, 'Name': 'Logistic Regression'}
        RF_results[year] = {'Predicted Champion': RF_champion, 'Prediction Correct': RF_prediction_correct, 'Contenders': RF_contenders, 'Name': 'Random Forest'}
        SVM_results[year] = {'Predicted Champion': SVM_champion, 'Prediction Correct': SVM_prediction_correct, 'Contenders': SVM_contenders, 'Name': 'Support Vector Machine'}
        GB_results[year] = {'Predicted Champion': GB_champion, 'Prediction Correct': GB_prediction_correct, 'Contenders': GB_contenders, 'Name': 'Gradient Boosting'}
        KNN_results[year] = {'Predicted Champion': KNN_champion, 'Prediction Correct': KNN_prediction_correct, 'Contenders': KNN_contenders, 'Name': 'K-Nearest Neighbors'}
        DT_results[year] = {'Predicted Champion': DT_champion, 'Prediction Correct': DT_prediction_correct, 'Contenders': DT_contenders, 'Name': 'Decision Tree'}
        NN_results[year] = {'Predicted Champion': NN_champion, 'Prediction Correct': NN_prediction_correct, 'Contenders': NN_contenders, 'Name': 'Neural Network'}
        NB_results[year] = {'Predicted Champion': NB_champion, 'Prediction Correct': NB_prediction_correct, 'Contenders': NB_contenders, 'Name': 'Naive Bayes'}
        ADA_results[year] = {'Predicted Champion': ADA_champion, 'Prediction Correct': ADA_prediction_correct, 'Contenders': ADA_contenders, 'Name': 'AdaBoost'}
    
    # Print the results & accuracy of the models
    results = [LR_results, RF_results, SVM_results, GB_results, KNN_results, DT_results, NN_results, NB_results, ADA_results]
    print_results(results)

    # Create a dataframe for the visualizations
    results_df = pd.DataFrame(columns=['Year', 'Model', 'Prediction Correct'])
    for result in results:
        for year, data in result.items():
            new_row = pd.DataFrame({'Year': [year], 'Model': [data['Name']], 'Prediction Correct': [data['Prediction Correct']]})
            results_df = pd.concat([results_df, new_row], ignore_index=True)
    results_df['Prediction Correct'] = results_df['Prediction Correct'].astype(int)
    results_df = results_df.pivot(index='Year', columns='Model', values='Prediction Correct').fillna(0)
    results_df = results_df.T

    # Display the visualizations
    display_heatmap(results_df)
    display_stacked_bar_chart(results_df, start_year, end_year)
    display_cumulative_accuracy_line_chart(results_df)
    display_model_score_by_year(results_df, results, start_year, end_year, championship_teams)

# %%
if __name__ == '__main__':
    main()
# Out:
# Training models for 1981
# Training models for 1982
# Training models for 1983
# Training models for 1984
# Training models for 1985
# Training models for 1986
# Training models for 1987
# Training models for 1988
# Training models for 1989
# Training models for 1990
# Training models for 1991
# Training models for 1992
# Training models for 1993
# Training models for 1994
# Training models for 1995
# Training models for 1996
# Training models for 1997
# Training models for 1998
# Training models for 1999
# Training models for 2000
# Training models for 2001
# Training models for 2002
# Training models for 2003
# Training models for 2004
# Training models for 2005
# Training models for 2006
# Training models for 2007
# Training models for 2008
# Training models for 2009
# Training models for 2010
# Training models for 2011
# Training models for 2012
# Training models for 2013
# Training models for 2014
# Training models for 2015
# Training models for 2016
# Training models for 2017
# Training models for 2018
# Training models for 2019
# Training models for 2020
# Training models for 2021
# Training models for 2022
# Training models for 2023
# Training models for 2024
# Year: 1981, Predicted Champion: Philadelphia 76ers, Prediction Correct: False, Contenders: {'Philadelphia 76ers': 0.42000422974906154, 'Milwaukee Bucks': 0.28793705868110586, 'Boston Celtics': 0.2478605920976684, 'Los Angeles Lakers': 0.12700898421855508, 'Phoenix Suns': 0.11579557776898743}
# Year: 1982, Predicted Champion: Los Angeles Lakers, Prediction Correct: True, Contenders: {'Los Angeles Lakers': 0.16490852922526786, 'Milwaukee Bucks': 0.12040027990688856, 'Boston Celtics': 0.0997321163651359, 'Philadelphia 76ers': 0.0884778658619989, 'Seattle SuperSonics': 0.07485620205032559}
# Year: 1983, Predicted Champion: Phoenix Suns, Prediction Correct: False, Contenders: {'Phoenix Suns': 0.1054815673058242, 'Philadelphia 76ers': 0.0947640644798582, 'Los Angeles Lakers': 0.09412304512892944, 'Milwaukee Bucks': 0.08385982409035231, 'Boston Celtics': 0.07132615205391823}
# Year: 1984, Predicted Champion: Boston Celtics, Prediction Correct: True, Contenders: {'Boston Celtics': 0.3985653263829293, 'Los Angeles Lakers': 0.06782977249727155, 'Detroit Pistons': 0.059162042192449915, 'Milwaukee Bucks': 0.03196432801487613, 'Portland Trail Blazers': 0.031155099966465358}
# Year: 1985, Predicted Champion: Los Angeles Lakers, Prediction Correct: True, Contenders: {'Los Angeles Lakers': 0.24102701407908594, 'Boston Celtics': 0.19816616962837, 'Milwaukee Bucks': 0.14521185850812066, 'Philadelphia 76ers': 0.06017302926833301, 'Detroit Pistons': 0.022598797384247665}
# Year: 1986, Predicted Champion: Boston Celtics, Prediction Correct: True, Contenders: {'Boston Celtics': 0.838579874567648, 'Milwaukee Bucks': 0.5392218070755032, 'Los Angeles Lakers': 0.37233756674041213, 'Houston Rockets': 0.013336370245317059, 'Atlanta Hawks': 0.011986833119665655}
# Year: 1987, Predicted Champion: Los Angeles Lakers, Prediction Correct: True, Contenders: {'Los Angeles Lakers': 0.7414347112052537, 'Boston Celtics': 0.31185561749028456, 'Atlanta Hawks': 0.2542537998343959, 'Dallas Mavericks': 0.1308952653115608, 'Detroit Pistons': 0.04141824339473859}
# Year: 1988, Predicted Champion: Boston Celtics, Prediction Correct: False, Contenders: {'Boston Celtics': 0.168925916270887, 'Detroit Pistons': 0.07300276144928712, 'Los Angeles Lakers': 0.07177103735426822, 'Chicago Bulls': 0.06354066293040198, 'Dallas Mavericks': 0.06040498167663191}
# Year: 1989, Predicted Champion: Cleveland Cavaliers, Prediction Correct: False, Contenders: {'Cleveland Cavaliers': 0.6378628411146008, 'Phoenix Suns': 0.39101166448136565, 'Los Angeles Lakers': 0.25873775563035434, 'Detroit Pistons': 0.1546652432858043, 'Atlanta Hawks': 0.05295669969035369}
# Year: 1990, Predicted Champion: Los Angeles Lakers, Prediction Correct: False, Contenders: {'Los Angeles Lakers': 0.30031454068732055, 'Phoenix Suns': 0.22893717463926103, 'Portland Trail Blazers': 0.11533835509441222, 'Detroit Pistons': 0.10497454915980577, 'Boston Celtics': 0.05376489969338688}
# Year: 1991, Predicted Champion: Chicago Bulls, Prediction Correct: True, Contenders: {'Chicago Bulls': 0.54327456756762, 'Portland Trail Blazers': 0.44941858650961775, 'Los Angeles Lakers': 0.22156340908672892, 'Boston Celtics': 0.19621962316582128, 'Phoenix Suns': 0.17736053868391452}
# Year: 1992, Predicted Champion: Chicago Bulls, Prediction Correct: True, Contenders: {'Chicago Bulls': 0.876169768318669, 'Portland Trail Blazers': 0.11881693904457256, 'Utah Jazz': 0.06870732357106286, 'Phoenix Suns': 0.05002244992218991, 'Cleveland Cavaliers': 0.04673240139451924}
# Year: 1993, Predicted Champion: Chicago Bulls, Prediction Correct: True, Contenders: {'Chicago Bulls': 0.3593823117021636, 'Cleveland Cavaliers': 0.16375132504693388, 'Seattle SuperSonics': 0.15245271582625716, 'Phoenix Suns': 0.10448856842668867, 'New York Knicks': 0.0906086328442784}
# Year: 1994, Predicted Champion: Seattle SuperSonics, Prediction Correct: False, Contenders: {'Seattle SuperSonics': 0.4313691679782031, 'New York Knicks': 0.1311342833733355, 'Phoenix Suns': 0.11378899337595051, 'Chicago Bulls': 0.08169653350035125, 'San Antonio Spurs': 0.07718489195159536}
# Year: 1995, Predicted Champion: Orlando Magic, Prediction Correct: False, Contenders: {'Orlando Magic': 0.12582697675911056, 'Utah Jazz': 0.12478413795518654, 'San Antonio Spurs': 0.08006022378330714, 'Seattle SuperSonics': 0.07721972058136009, 'Chicago Bulls': 0.04894428108067498}
# Year: 1996, Predicted Champion: Chicago Bulls, Prediction Correct: True, Contenders: {'Chicago Bulls': 0.8630188344731785, 'Orlando Magic': 0.16382549837384283, 'San Antonio Spurs': 0.15509909730240187, 'Los Angeles Lakers': 0.06497340904382505, 'Seattle SuperSonics': 0.05311133799194702}
# Year: 1997, Predicted Champion: Chicago Bulls, Prediction Correct: True, Contenders: {'Chicago Bulls': 0.9556244066033234, 'Seattle SuperSonics': 0.12450405351515893, 'Utah Jazz': 0.11550319551814152, 'Atlanta Hawks': 0.08633278822199383, 'Houston Rockets': 0.053084416211679794}
# Year: 1998, Predicted Champion: Chicago Bulls, Prediction Correct: True, Contenders: {'Chicago Bulls': 0.6774696854878721, 'Seattle SuperSonics': 0.15871011117840234, 'Utah Jazz': 0.10368453135665448, 'Miami Heat': 0.0837384877771458, 'Los Angeles Lakers': 0.08264420955575032}
# Year: 1999, Predicted Champion: San Antonio Spurs, Prediction Correct: True, Contenders: {'San Antonio Spurs': 0.19657183140858378, 'Utah Jazz': 0.11370968354822907, 'Indiana Pacers': 0.040464221583065334, 'Portland Trail Blazers': 0.038729948896760416, 'Miami Heat': 0.032895087975518766}
# Year: 2000, Predicted Champion: Los Angeles Lakers, Prediction Correct: True, Contenders: {'Los Angeles Lakers': 0.35460185007374506, 'San Antonio Spurs': 0.24675393209420446, 'Portland Trail Blazers': 0.17128648883971442, 'Indiana Pacers': 0.057995456567717596, 'Phoenix Suns': 0.03599857324223115}
# Year: 2001, Predicted Champion: San Antonio Spurs, Prediction Correct: False, Contenders: {'San Antonio Spurs': 0.1688723868754562, 'Sacramento Kings': 0.11878482903245739, 'Portland Trail Blazers': 0.08526981891585972, 'Los Angeles Lakers': 0.06634341579373079, 'Philadelphia 76ers': 0.031912107798481006}
# Year: 2002, Predicted Champion: Los Angeles Lakers, Prediction Correct: True, Contenders: {'Los Angeles Lakers': 0.5382346927494359, 'Sacramento Kings': 0.2425820704323523, 'San Antonio Spurs': 0.09903097843131738, 'Minnesota Timberwolves': 0.024485539624654443, 'New Jersey Nets': 0.01955278847166684}
# Year: 2003, Predicted Champion: Sacramento Kings, Prediction Correct: False, Contenders: {'Sacramento Kings': 0.5387383354685565, 'Dallas Mavericks': 0.18618255184924642, 'San Antonio Spurs': 0.1066006958758832, 'Los Angeles Lakers': 0.06739311209816004, 'New Jersey Nets': 0.04553486754218916}
# Year: 2004, Predicted Champion: San Antonio Spurs, Prediction Correct: False, Contenders: {'San Antonio Spurs': 0.49356783790849107, 'Minnesota Timberwolves': 0.1380902627560312, 'Dallas Mavericks': 0.12577578352026655, 'Sacramento Kings': 0.07838871237464298, 'Detroit Pistons': 0.05974042181754915}
# Year: 2005, Predicted Champion: San Antonio Spurs, Prediction Correct: True, Contenders: {'San Antonio Spurs': 0.2463907774557123, 'Detroit Pistons': 0.15658209371613738, 'Phoenix Suns': 0.13676793703280646, 'Miami Heat': 0.056297788045251464, 'Dallas Mavericks': 0.02749074284631}
# Year: 2006, Predicted Champion: Detroit Pistons, Prediction Correct: False, Contenders: {'Detroit Pistons': 0.6389662128392821, 'San Antonio Spurs': 0.5772139821842813, 'Phoenix Suns': 0.12475054873052942, 'Dallas Mavericks': 0.08212291256069376, 'Miami Heat': 0.029942792941983966}
# Year: 2007, Predicted Champion: Dallas Mavericks, Prediction Correct: False, Contenders: {'Dallas Mavericks': 0.41787024004797474, 'San Antonio Spurs': 0.35133543909115433, 'Phoenix Suns': 0.32558161684097486, 'Detroit Pistons': 0.04919040116832523, 'Houston Rockets': 0.04116910280139356}
# Year: 2008, Predicted Champion: Boston Celtics, Prediction Correct: True, Contenders: {'Boston Celtics': 0.20270384708753744, 'San Antonio Spurs': 0.18731128494312252, 'Detroit Pistons': 0.14219876913535362, 'Los Angeles Lakers': 0.0812910915270146, 'Houston Rockets': 0.06253646318291958}
# Year: 2009, Predicted Champion: Boston Celtics, Prediction Correct: False, Contenders: {'Boston Celtics': 0.5010070748677097, 'Cleveland Cavaliers': 0.49187399286104205, 'Los Angeles Lakers': 0.45363368905712004, 'Orlando Magic': 0.12530842885360816, 'San Antonio Spurs': 0.037353097329987116}
# Year: 2010, Predicted Champion: Orlando Magic, Prediction Correct: False, Contenders: {'Orlando Magic': 0.35798480828918716, 'Los Angeles Lakers': 0.2780957906120974, 'Cleveland Cavaliers': 0.2748712676654104, 'San Antonio Spurs': 0.049340199659657934, 'Atlanta Hawks': 0.03768651890354329}
# Year: 2011, Predicted Champion: Los Angeles Lakers, Prediction Correct: False, Contenders: {'Los Angeles Lakers': 0.4195310854395691, 'Chicago Bulls': 0.16641484849449728, 'Boston Celtics': 0.13505486012851856, 'San Antonio Spurs': 0.08903020239061511, 'Orlando Magic': 0.0820728080601852}
# Year: 2012, Predicted Champion: Chicago Bulls, Prediction Correct: False, Contenders: {'Chicago Bulls': 0.5678049951899423, 'Miami Heat': 0.22416613417507927, 'San Antonio Spurs': 0.20313833981291013, 'Oklahoma City Thunder': 0.1377976147096789, 'Los Angeles Lakers': 0.02304180301783769}
# Year: 2013, Predicted Champion: Miami Heat, Prediction Correct: True, Contenders: {'Miami Heat': 0.46861712787331905, 'Oklahoma City Thunder': 0.4443715252777862, 'San Antonio Spurs': 0.19683477719608075, 'Los Angeles Clippers': 0.05703615489973663, 'Denver Nuggets': 0.05301883321259864}
# Year: 2014, Predicted Champion: San Antonio Spurs, Prediction Correct: True, Contenders: {'San Antonio Spurs': 0.6343250567409009, 'Miami Heat': 0.15427346884156418, 'Indiana Pacers': 0.1046093022362485, 'Oklahoma City Thunder': 0.09802529507342529, 'Golden State Warriors': 0.04959595854006651}
# Year: 2015, Predicted Champion: Golden State Warriors, Prediction Correct: True, Contenders: {'Golden State Warriors': 0.5410043125872191, 'San Antonio Spurs': 0.37010430632113756, 'Atlanta Hawks': 0.0614842580197052, 'Portland Trail Blazers': 0.05212339606630445, 'Cleveland Cavaliers': 0.04590827159306059}
# Year: 2016, Predicted Champion: Golden State Warriors, Prediction Correct: False, Contenders: {'Golden State Warriors': 0.92604961509153, 'San Antonio Spurs': 0.5361489832598595, 'Cleveland Cavaliers': 0.1434594225482719, 'Oklahoma City Thunder': 0.06720899091798029, 'Atlanta Hawks': 0.028137612231152326}
# Year: 2017, Predicted Champion: Golden State Warriors, Prediction Correct: True, Contenders: {'Golden State Warriors': 0.8897384916338736, 'San Antonio Spurs': 0.13975387428731745, 'Cleveland Cavaliers': 0.06033290905220685, 'Houston Rockets': 0.019347613136799446, 'Toronto Raptors': 0.014743639359445277}
# Year: 2018, Predicted Champion: Golden State Warriors, Prediction Correct: True, Contenders: {'Golden State Warriors': 0.45681533208323927, 'Houston Rockets': 0.1874295402085355, 'Toronto Raptors': 0.06997951260446786, 'Boston Celtics': 0.03374708473754948, 'Utah Jazz': 0.02642185035164963}
# Year: 2019, Predicted Champion: Golden State Warriors, Prediction Correct: False, Contenders: {'Golden State Warriors': 0.6074111277098772, 'Milwaukee Bucks': 0.21728943778308699, 'Toronto Raptors': 0.06711192261848334, 'Boston Celtics': 0.05017378354998874, 'Utah Jazz': 0.046749506680155484}
# Year: 2020, Predicted Champion: Milwaukee Bucks, Prediction Correct: False, Contenders: {'Milwaukee Bucks': 0.48109273115222567, 'Toronto Raptors': 0.16979451922362862, 'Los Angeles Lakers': 0.07784747736375124, 'Los Angeles Clippers': 0.052113913683120495, 'Boston Celtics': 0.03862778109551861}
# Year: 2021, Predicted Champion: Utah Jazz, Prediction Correct: False, Contenders: {'Utah Jazz': 0.2708036780792582, 'Milwaukee Bucks': 0.10965658955515785, 'Los Angeles Clippers': 0.09456620065902974, 'Los Angeles Lakers': 0.08107670805324035, 'Denver Nuggets': 0.07266991055652691}
# Year: 2022, Predicted Champion: Phoenix Suns, Prediction Correct: False, Contenders: {'Phoenix Suns': 0.4410513888314206, 'Boston Celtics': 0.08486607068810008, 'Milwaukee Bucks': 0.08148295294832215, 'Utah Jazz': 0.06290451752728025, 'Memphis Grizzlies': 0.051288342067901636}
# Year: 2023, Predicted Champion: Boston Celtics, Prediction Correct: False, Contenders: {'Boston Celtics': 0.3382428415429209, 'Milwaukee Bucks': 0.1272696380438734, 'Golden State Warriors': 0.074344618431123, 'Denver Nuggets': 0.04128711141744286, 'Memphis Grizzlies': 0.03421657948237949}
# Year: 2024, Predicted Champion: Boston Celtics, Prediction Correct: True, Contenders: {'Boston Celtics': 0.6839863593794036, 'Denver Nuggets': 0.2186223401996933, 'Minnesota Timberwolves': 0.05893148940961882, 'Oklahoma City Thunder': 0.056903024058629216, 'New York Knicks': 0.032213500580123684}
# Model Accuracy: 0.5 (22/44) [Logistic Regression]
#
#
# Year: 1981, Predicted Champion: Philadelphia 76ers, Prediction Correct: False, Contenders: {'Philadelphia 76ers': 0.29, 'Boston Celtics': 0.28, 'Los Angeles Lakers': 0.18, 'Milwaukee Bucks': 0.1, 'Chicago Bulls': 0.09}
# Year: 1982, Predicted Champion: Boston Celtics, Prediction Correct: False, Contenders: {'Boston Celtics': 0.29, 'Los Angeles Lakers': 0.24, 'Denver Nuggets': 0.2, 'San Antonio Spurs': 0.16, 'Philadelphia 76ers': 0.14}
# Year: 1983, Predicted Champion: Los Angeles Lakers, Prediction Correct: False, Contenders: {'Los Angeles Lakers': 0.67, 'Philadelphia 76ers': 0.3, 'Boston Celtics': 0.19, 'San Antonio Spurs': 0.07, 'Milwaukee Bucks': 0.05}
# Year: 1984, Predicted Champion: Los Angeles Lakers, Prediction Correct: False, Contenders: {'Los Angeles Lakers': 0.45, 'Philadelphia 76ers': 0.22, 'Boston Celtics': 0.22, 'Seattle SuperSonics': 0.07, 'Detroit Pistons': 0.05}
# Year: 1985, Predicted Champion: Los Angeles Lakers, Prediction Correct: True, Contenders: {'Los Angeles Lakers': 0.5, 'Boston Celtics': 0.48, 'Philadelphia 76ers': 0.22, 'Milwaukee Bucks': 0.21, 'Washington Bullets': 0.11}
# Year: 1986, Predicted Champion: Los Angeles Lakers, Prediction Correct: False, Contenders: {'Los Angeles Lakers': 0.67, 'Boston Celtics': 0.58, 'Dallas Mavericks': 0.08, 'Milwaukee Bucks': 0.07, 'Detroit Pistons': 0.02}
# Year: 1987, Predicted Champion: Los Angeles Lakers, Prediction Correct: True, Contenders: {'Los Angeles Lakers': 0.66, 'Boston Celtics': 0.39, 'Philadelphia 76ers': 0.08, 'Dallas Mavericks': 0.07, 'Indiana Pacers': 0.03}
# Year: 1988, Predicted Champion: Boston Celtics, Prediction Correct: False, Contenders: {'Boston Celtics': 0.37, 'Los Angeles Lakers': 0.27, 'Dallas Mavericks': 0.14, 'Portland Trail Blazers': 0.05, 'Detroit Pistons': 0.05}
# Year: 1989, Predicted Champion: Cleveland Cavaliers, Prediction Correct: False, Contenders: {'Cleveland Cavaliers': 0.32, 'Detroit Pistons': 0.24, 'Phoenix Suns': 0.11, 'Los Angeles Lakers': 0.11, 'New York Knicks': 0.1}
# Year: 1990, Predicted Champion: Los Angeles Lakers, Prediction Correct: False, Contenders: {'Los Angeles Lakers': 0.58, 'Phoenix Suns': 0.12, 'Detroit Pistons': 0.11, 'Portland Trail Blazers': 0.09, 'Utah Jazz': 0.07}
# Year: 1991, Predicted Champion: Portland Trail Blazers, Prediction Correct: False, Contenders: {'Portland Trail Blazers': 0.45, 'Chicago Bulls': 0.22, 'Los Angeles Lakers': 0.2, 'Boston Celtics': 0.09, 'Detroit Pistons': 0.08}
# Year: 1992, Predicted Champion: Chicago Bulls, Prediction Correct: True, Contenders: {'Chicago Bulls': 0.71, 'Cleveland Cavaliers': 0.09, 'Portland Trail Blazers': 0.06, 'Phoenix Suns': 0.03, 'Golden State Warriors': 0.03}
# Year: 1993, Predicted Champion: Phoenix Suns, Prediction Correct: False, Contenders: {'Phoenix Suns': 0.27, 'Chicago Bulls': 0.23, 'New York Knicks': 0.15, 'Cleveland Cavaliers': 0.09, 'Boston Celtics': 0.05}
# Year: 1994, Predicted Champion: Seattle SuperSonics, Prediction Correct: False, Contenders: {'Seattle SuperSonics': 0.43, 'Chicago Bulls': 0.16, 'Golden State Warriors': 0.05, 'New York Knicks': 0.05, 'Atlanta Hawks': 0.04}
# Year: 1995, Predicted Champion: Orlando Magic, Prediction Correct: False, Contenders: {'Orlando Magic': 0.16, 'Phoenix Suns': 0.14, 'San Antonio Spurs': 0.14, 'Atlanta Hawks': 0.11, 'New York Knicks': 0.11}
# Year: 1996, Predicted Champion: Chicago Bulls, Prediction Correct: True, Contenders: {'Chicago Bulls': 0.77, 'Houston Rockets': 0.17, 'Orlando Magic': 0.15, 'San Antonio Spurs': 0.11, 'Los Angeles Lakers': 0.04}
# Year: 1997, Predicted Champion: Chicago Bulls, Prediction Correct: True, Contenders: {'Chicago Bulls': 0.88, 'Utah Jazz': 0.2, 'Houston Rockets': 0.15, 'Miami Heat': 0.14, 'New York Knicks': 0.06}
# Year: 1998, Predicted Champion: Chicago Bulls, Prediction Correct: True, Contenders: {'Chicago Bulls': 0.52, 'Seattle SuperSonics': 0.29, 'Los Angeles Lakers': 0.13, 'Utah Jazz': 0.13, 'Phoenix Suns': 0.09}
# Year: 1999, Predicted Champion: San Antonio Spurs, Prediction Correct: True, Contenders: {'San Antonio Spurs': 0.32, 'Utah Jazz': 0.22, 'Sacramento Kings': 0.06, 'Miami Heat': 0.04, 'Houston Rockets': 0.02}
# Year: 2000, Predicted Champion: Los Angeles Lakers, Prediction Correct: True, Contenders: {'Los Angeles Lakers': 0.7, 'San Antonio Spurs': 0.23, 'Indiana Pacers': 0.1, 'Seattle SuperSonics': 0.09, 'Portland Trail Blazers': 0.07}
# Year: 2001, Predicted Champion: San Antonio Spurs, Prediction Correct: False, Contenders: {'San Antonio Spurs': 0.38, 'Los Angeles Lakers': 0.23, 'Minnesota Timberwolves': 0.08, 'Milwaukee Bucks': 0.04, 'Dallas Mavericks': 0.04}
# Year: 2002, Predicted Champion: Los Angeles Lakers, Prediction Correct: True, Contenders: {'Los Angeles Lakers': 0.63, 'Sacramento Kings': 0.41, 'Orlando Magic': 0.14, 'Boston Celtics': 0.03, 'Dallas Mavericks': 0.02}
# Year: 2003, Predicted Champion: San Antonio Spurs, Prediction Correct: True, Contenders: {'San Antonio Spurs': 0.34, 'Sacramento Kings': 0.31, 'Los Angeles Lakers': 0.24, 'Dallas Mavericks': 0.23, 'Boston Celtics': 0.03}
# Year: 2004, Predicted Champion: San Antonio Spurs, Prediction Correct: False, Contenders: {'San Antonio Spurs': 0.29, 'Los Angeles Lakers': 0.15, 'Minnesota Timberwolves': 0.05, 'Indiana Pacers': 0.04, 'Dallas Mavericks': 0.03}
# Year: 2005, Predicted Champion: Phoenix Suns, Prediction Correct: False, Contenders: {'Phoenix Suns': 0.19, 'San Antonio Spurs': 0.18, 'Detroit Pistons': 0.15, 'Miami Heat': 0.12, 'Memphis Grizzlies': 0.02}
# Year: 2006, Predicted Champion: Detroit Pistons, Prediction Correct: False, Contenders: {'Detroit Pistons': 0.73, 'San Antonio Spurs': 0.48, 'Phoenix Suns': 0.22, 'Dallas Mavericks': 0.08, 'Indiana Pacers': 0.02}
# Year: 2007, Predicted Champion: Dallas Mavericks, Prediction Correct: False, Contenders: {'Dallas Mavericks': 0.49, 'San Antonio Spurs': 0.28, 'Phoenix Suns': 0.14, 'Utah Jazz': 0.11, 'Miami Heat': 0.08}
# Year: 2008, Predicted Champion: Boston Celtics, Prediction Correct: True, Contenders: {'Boston Celtics': 0.49, 'San Antonio Spurs': 0.14, 'New Orleans Hornets': 0.09, 'Los Angeles Lakers': 0.09, 'Detroit Pistons': 0.04}
# Year: 2009, Predicted Champion: Cleveland Cavaliers, Prediction Correct: False, Contenders: {'Cleveland Cavaliers': 0.72, 'Los Angeles Lakers': 0.45, 'San Antonio Spurs': 0.12, 'Boston Celtics': 0.12, 'Orlando Magic': 0.09}
# Year: 2010, Predicted Champion: Cleveland Cavaliers, Prediction Correct: False, Contenders: {'Cleveland Cavaliers': 0.33, 'Orlando Magic': 0.22, 'Los Angeles Lakers': 0.15, 'Charlotte Bobcats': 0.05, 'Phoenix Suns': 0.04}
# Year: 2011, Predicted Champion: Los Angeles Lakers, Prediction Correct: False, Contenders: {'Los Angeles Lakers': 0.39, 'Chicago Bulls': 0.22, 'Boston Celtics': 0.19, 'Miami Heat': 0.15, 'Orlando Magic': 0.05}
# Year: 2012, Predicted Champion: Chicago Bulls, Prediction Correct: False, Contenders: {'Chicago Bulls': 0.44, 'Miami Heat': 0.35, 'San Antonio Spurs': 0.31, 'Dallas Mavericks': 0.15, 'Oklahoma City Thunder': 0.09}
# Year: 2013, Predicted Champion: Miami Heat, Prediction Correct: True, Contenders: {'Miami Heat': 0.47, 'Oklahoma City Thunder': 0.36, 'Denver Nuggets': 0.05, 'San Antonio Spurs': 0.04, 'Boston Celtics': 0.03}
# Year: 2014, Predicted Champion: Miami Heat, Prediction Correct: False, Contenders: {'Miami Heat': 0.38, 'San Antonio Spurs': 0.25, 'Indiana Pacers': 0.08, 'Charlotte Bobcats': 0.03, 'Oklahoma City Thunder': 0.03}
# Year: 2015, Predicted Champion: Golden State Warriors, Prediction Correct: True, Contenders: {'Golden State Warriors': 0.62, 'Atlanta Hawks': 0.31, 'Cleveland Cavaliers': 0.18, 'San Antonio Spurs': 0.15, 'Memphis Grizzlies': 0.08}
# Year: 2016, Predicted Champion: Golden State Warriors, Prediction Correct: False, Contenders: {'Golden State Warriors': 0.76, 'San Antonio Spurs': 0.47, 'Cleveland Cavaliers': 0.15, 'Charlotte Hornets': 0.03, 'Atlanta Hawks': 0.02}
# Year: 2017, Predicted Champion: Golden State Warriors, Prediction Correct: True, Contenders: {'Golden State Warriors': 0.7, 'Cleveland Cavaliers': 0.15, 'San Antonio Spurs': 0.08, 'Chicago Bulls': 0.03, 'Houston Rockets': 0.03}
# Year: 2018, Predicted Champion: Golden State Warriors, Prediction Correct: True, Contenders: {'Golden State Warriors': 0.54, 'Houston Rockets': 0.31, 'San Antonio Spurs': 0.03, 'Cleveland Cavaliers': 0.02, 'Toronto Raptors': 0.02}
# Year: 2019, Predicted Champion: Golden State Warriors, Prediction Correct: False, Contenders: {'Golden State Warriors': 0.51, 'Milwaukee Bucks': 0.48, 'Houston Rockets': 0.04, 'Boston Celtics': 0.03, 'Toronto Raptors': 0.03}
# Year: 2020, Predicted Champion: Milwaukee Bucks, Prediction Correct: False, Contenders: {'Milwaukee Bucks': 0.34, 'Los Angeles Lakers': 0.17, 'Los Angeles Clippers': 0.13, 'Toronto Raptors': 0.13, 'Dallas Mavericks': 0.02}
# Year: 2021, Predicted Champion: Utah Jazz, Prediction Correct: False, Contenders: {'Utah Jazz': 0.27, 'Brooklyn Nets': 0.14, 'Phoenix Suns': 0.12, 'Miami Heat': 0.06, 'Milwaukee Bucks': 0.06}
# Year: 2022, Predicted Champion: Phoenix Suns, Prediction Correct: False, Contenders: {'Phoenix Suns': 0.57, 'Utah Jazz': 0.17, 'Milwaukee Bucks': 0.13, 'Boston Celtics': 0.12, 'Golden State Warriors': 0.09}
# Year: 2023, Predicted Champion: Milwaukee Bucks, Prediction Correct: False, Contenders: {'Boston Celtics': 0.28, 'Milwaukee Bucks': 0.28, 'Golden State Warriors': 0.27, 'Denver Nuggets': 0.09, 'Cleveland Cavaliers': 0.06}
# Year: 2024, Predicted Champion: Boston Celtics, Prediction Correct: True, Contenders: {'Boston Celtics': 0.47, 'Denver Nuggets': 0.32, 'Oklahoma City Thunder': 0.22, 'Milwaukee Bucks': 0.1, 'Minnesota Timberwolves': 0.08}
# Model Accuracy: 0.36363636363636365 (16/44) [Random Forest]
#
#
# Year: 1981, Predicted Champion: Indiana Pacers, Prediction Correct: False, Contenders: {'Indiana Pacers': 0.12618141511873396, 'New York Knicks': 0.126158177063373, 'Portland Trail Blazers': 0.12615018240259998, 'San Antonio Spurs': 0.12614604263247575, 'Chicago Bulls': 0.12613613637458382}
# Year: 1982, Predicted Champion: New Jersey Nets, Prediction Correct: False, Contenders: {'New Jersey Nets': 0.11397313647251985, 'Atlanta Hawks': 0.11076268511483776, 'Washington Bullets': 0.09479763012438873, 'San Antonio Spurs': 0.08414922295206595, 'Phoenix Suns': 0.08051758187549538}
# Year: 1983, Predicted Champion: Atlanta Hawks, Prediction Correct: False, Contenders: {'Atlanta Hawks': 0.1414776132624082, 'New York Knicks': 0.10831766645486549, 'New Jersey Nets': 0.09107883298731173, 'Los Angeles Lakers': 0.08580026365906653, 'Denver Nuggets': 0.0839336812752178}
# Year: 1984, Predicted Champion: Atlanta Hawks, Prediction Correct: False, Contenders: {'Atlanta Hawks': 0.12672384514642715, 'New Jersey Nets': 0.11608236058066997, 'Kansas City Kings': 0.11455111866697039, 'Denver Nuggets': 0.10437485218358288, 'Washington Bullets': 0.1017016644163903}
# Year: 1985, Predicted Champion: Boston Celtics, Prediction Correct: False, Contenders: {'Boston Celtics': 0.10211073051630233, 'Milwaukee Bucks': 0.10095547012822655, 'Los Angeles Lakers': 0.09741153062996544, 'Philadelphia 76ers': 0.07998573175812126, 'Detroit Pistons': 0.07028859687436906}
# Year: 1986, Predicted Champion: Los Angeles Lakers, Prediction Correct: False, Contenders: {'Los Angeles Lakers': 0.10092576637348215, 'Boston Celtics': 0.09074772501104485, 'Houston Rockets': 0.06793527670977202, 'Milwaukee Bucks': 0.0626657650401333, 'Dallas Mavericks': 0.06120146618198687}
# Year: 1987, Predicted Champion: Los Angeles Lakers, Prediction Correct: True, Contenders: {'Los Angeles Lakers': 0.10127666624010485, 'Dallas Mavericks': 0.08736375915513389, 'Atlanta Hawks': 0.07974525026672108, 'Boston Celtics': 0.07824450315883758, 'Detroit Pistons': 0.07663025837818767}
# Year: 1988, Predicted Champion: Chicago Bulls, Prediction Correct: False, Contenders: {'Chicago Bulls': 0.1181852187456454, 'Dallas Mavericks': 0.10265439219649751, 'Denver Nuggets': 0.0845306963738685, 'Boston Celtics': 0.08374914716122686, 'San Antonio Spurs': 0.08078924983478236}
# Year: 1989, Predicted Champion: Cleveland Cavaliers, Prediction Correct: False, Contenders: {'Cleveland Cavaliers': 0.18645230484111472, 'Phoenix Suns': 0.15702625660993505, 'New York Knicks': 0.09838037276228086, 'Los Angeles Lakers': 0.09136426180382333, 'Detroit Pistons': 0.07884739943520397}
# Year: 1990, Predicted Champion: Phoenix Suns, Prediction Correct: False, Contenders: {'Phoenix Suns': 0.10915076697976753, 'Los Angeles Lakers': 0.10211229324143654, 'Boston Celtics': 0.0821388002811967, 'Philadelphia 76ers': 0.07932503482005664, 'Utah Jazz': 0.0767522458082736}
# Year: 1991, Predicted Champion: Detroit Pistons, Prediction Correct: False, Contenders: {'Detroit Pistons': 0.1506228443342172, 'Chicago Bulls': 0.12356920152721856, 'Portland Trail Blazers': 0.12135013905211044, 'Boston Celtics': 0.1026750102421038, 'Los Angeles Lakers': 0.09152417295375051}
# Year: 1992, Predicted Champion: Chicago Bulls, Prediction Correct: True, Contenders: {'Chicago Bulls': 0.20962263377309254, 'Cleveland Cavaliers': 0.07927250003539132, 'Portland Trail Blazers': 0.06349015061599526, 'Phoenix Suns': 0.06177615783266458, 'New York Knicks': 0.06155190094071448}
# Year: 1993, Predicted Champion: Chicago Bulls, Prediction Correct: True, Contenders: {'Chicago Bulls': 0.11311927621327367, 'Houston Rockets': 0.06458782893868285, 'Seattle SuperSonics': 0.06332155031144526, 'Phoenix Suns': 0.06020647514541637, 'San Antonio Spurs': 0.05033532875537089}
# Year: 1994, Predicted Champion: Seattle SuperSonics, Prediction Correct: False, Contenders: {'Seattle SuperSonics': 0.09680083490146497, 'Chicago Bulls': 0.06648864527159035, 'Atlanta Hawks': 0.0657614399015552, 'Orlando Magic': 0.06426725090904394, 'Golden State Warriors': 0.06366325015258315}
# Year: 1995, Predicted Champion: Orlando Magic, Prediction Correct: False, Contenders: {'Orlando Magic': 0.0717827172687303, 'Atlanta Hawks': 0.06696273689231381, 'Phoenix Suns': 0.06630888112123412, 'Utah Jazz': 0.06550143765810217, 'Chicago Bulls': 0.06473192195711795}
# Year: 1996, Predicted Champion: Chicago Bulls, Prediction Correct: True, Contenders: {'Chicago Bulls': 0.13892803900661066, 'Houston Rockets': 0.08844265811887202, 'Los Angeles Lakers': 0.07017958651361478, 'New York Knicks': 0.06562477488126255, 'Cleveland Cavaliers': 0.06199715579028612}
# Year: 1997, Predicted Champion: Chicago Bulls, Prediction Correct: True, Contenders: {'Chicago Bulls': 0.9999944934777352, 'Seattle SuperSonics': 0.1482799324123893, 'Utah Jazz': 0.08697108485575675, 'Houston Rockets': 0.06660163641893378, 'Orlando Magic': 0.05957692508378123}
# Year: 1998, Predicted Champion: Chicago Bulls, Prediction Correct: True, Contenders: {'Chicago Bulls': 0.8817723867330773, 'Seattle SuperSonics': 0.08410208514858743, 'San Antonio Spurs': 0.061498370407502105, 'Los Angeles Lakers': 0.06104473001002323, 'Houston Rockets': 0.060551939177995076}
# Year: 1999, Predicted Champion: San Antonio Spurs, Prediction Correct: True, Contenders: {'San Antonio Spurs': 0.061267349693581434, 'Orlando Magic': 0.060958455387493525, 'Houston Rockets': 0.05363031685833733, 'Detroit Pistons': 0.05217241011693867, 'Philadelphia 76ers': 0.05206309490865631}
# Year: 2000, Predicted Champion: San Antonio Spurs, Prediction Correct: False, Contenders: {'San Antonio Spurs': 0.1732330102230166, 'Los Angeles Lakers': 0.07891336716347402, 'Miami Heat': 0.05519497995550939, 'Minnesota Timberwolves': 0.05497554386150537, 'Phoenix Suns': 0.05443703988833234}
# Year: 2001, Predicted Champion: San Antonio Spurs, Prediction Correct: False, Contenders: {'San Antonio Spurs': 0.06537518144966681, 'Los Angeles Lakers': 0.05984619187875068, 'Indiana Pacers': 0.052227354860046066, 'Minnesota Timberwolves': 0.04782901957763266, 'Philadelphia 76ers': 0.04730356059314136}
# Year: 2002, Predicted Champion: Los Angeles Lakers, Prediction Correct: True, Contenders: {'Los Angeles Lakers': 0.44100441392224743, 'Sacramento Kings': 0.0772735482553843, 'Seattle SuperSonics': 0.059972372139455915, 'Toronto Raptors': 0.05867583031880324, 'New Jersey Nets': 0.05757754946638188}
# Year: 2003, Predicted Champion: Dallas Mavericks, Prediction Correct: False, Contenders: {'Dallas Mavericks': 0.07104247443304179, 'Los Angeles Lakers': 0.06284330873698699, 'San Antonio Spurs': 0.05461883363614316, 'Minnesota Timberwolves': 0.05348088085156137, 'Portland Trail Blazers': 0.05168547231173484}
# Year: 2004, Predicted Champion: San Antonio Spurs, Prediction Correct: False, Contenders: {'San Antonio Spurs': 0.9631231774507371, 'Minnesota Timberwolves': 0.047803752522929885, 'Boston Celtics': 0.043131735919584975, 'Memphis Grizzlies': 0.04275269626472643, 'Houston Rockets': 0.04247173296935772}
# Year: 2005, Predicted Champion: Detroit Pistons, Prediction Correct: False, Contenders: {'Detroit Pistons': 0.11588051536449415, 'San Antonio Spurs': 0.1102989189670524, 'Phoenix Suns': 0.06158258604418561, 'New Jersey Nets': 0.05311642897944227, 'Sacramento Kings': 0.05169176744228738}
# Year: 2006, Predicted Champion: San Antonio Spurs, Prediction Correct: False, Contenders: {'San Antonio Spurs': 0.3614807119996105, 'Detroit Pistons': 0.3057661680390172, 'Indiana Pacers': 0.0589585047128298, 'Dallas Mavericks': 0.053121819793816034, 'Memphis Grizzlies': 0.04946576709966109}
# Year: 2007, Predicted Champion: Dallas Mavericks, Prediction Correct: False, Contenders: {'Dallas Mavericks': 0.3870916772354202, 'San Antonio Spurs': 0.36714899476062185, 'Phoenix Suns': 0.09921659528320977, 'Miami Heat': 0.08543550455876588, 'Cleveland Cavaliers': 0.06258926369864366}
# Year: 2008, Predicted Champion: Boston Celtics, Prediction Correct: True, Contenders: {'Boston Celtics': 0.0854817149682753, 'New Orleans Hornets': 0.0653909139233799, 'Cleveland Cavaliers': 0.058996969824416, 'Houston Rockets': 0.04982739923656642, 'Detroit Pistons': 0.039288171465072845}
# Year: 2009, Predicted Champion: Cleveland Cavaliers, Prediction Correct: False, Contenders: {'Cleveland Cavaliers': 0.4730390860294298, 'Los Angeles Lakers': 0.21447285504187577, 'Boston Celtics': 0.18220762577815747, 'Orlando Magic': 0.07941541265182425, 'Detroit Pistons': 0.06129666927123411}
# Year: 2010, Predicted Champion: Orlando Magic, Prediction Correct: False, Contenders: {'Orlando Magic': 0.06686514698071308, 'Dallas Mavericks': 0.05869477866197048, 'Phoenix Suns': 0.057266237821325894, 'Los Angeles Lakers': 0.04602297218526859, 'Oklahoma City Thunder': 0.0453951124488892}
# Year: 2011, Predicted Champion: Los Angeles Lakers, Prediction Correct: False, Contenders: {'Los Angeles Lakers': 0.18027160403665182, 'Chicago Bulls': 0.06591257657890992, 'Memphis Grizzlies': 0.0441091612081564, 'San Antonio Spurs': 0.04260094843284408, 'Dallas Mavericks': 0.036996095580640924}
# Year: 2012, Predicted Champion: Chicago Bulls, Prediction Correct: False, Contenders: {'Chicago Bulls': 0.10462982842695644, 'San Antonio Spurs': 0.06794051959963042, 'Los Angeles Lakers': 0.06659658512123358, 'Atlanta Hawks': 0.06540867135711836, 'Boston Celtics': 0.0649026985800514}
# Year: 2013, Predicted Champion: Oklahoma City Thunder, Prediction Correct: False, Contenders: {'Oklahoma City Thunder': 0.14966414969365668, 'Miami Heat': 0.0790134750669637, 'Indiana Pacers': 0.06460618292112474, 'Los Angeles Lakers': 0.062282255435007775, 'Boston Celtics': 0.06093348737011476}
# Year: 2014, Predicted Champion: San Antonio Spurs, Prediction Correct: True, Contenders: {'San Antonio Spurs': 0.3091820432967275, 'Miami Heat': 0.11115438773376467, 'Oklahoma City Thunder': 0.06704279397885188, 'Golden State Warriors': 0.05744961775663449, 'Chicago Bulls': 0.0566829892795157}
# Year: 2015, Predicted Champion: Golden State Warriors, Prediction Correct: True, Contenders: {'Golden State Warriors': 0.555859187322284, 'San Antonio Spurs': 0.16190136226954616, 'Cleveland Cavaliers': 0.06992185181057585, 'Portland Trail Blazers': 0.059439577554689996, 'Atlanta Hawks': 0.051961285516203326}
# Year: 2016, Predicted Champion: Golden State Warriors, Prediction Correct: False, Contenders: {'Golden State Warriors': 0.9947498582761269, 'San Antonio Spurs': 0.902492258812671, 'Oklahoma City Thunder': 0.060330980380054924, 'Houston Rockets': 0.057158265148410166, 'Cleveland Cavaliers': 0.05493713469933921}
# Year: 2017, Predicted Champion: Golden State Warriors, Prediction Correct: True, Contenders: {'Golden State Warriors': 0.8171152736904403, 'San Antonio Spurs': 0.08143461174221686, 'Cleveland Cavaliers': 0.05845399278164598, 'Oklahoma City Thunder': 0.05321961443272948, 'Washington Wizards': 0.04796936405457773}
# Year: 2018, Predicted Champion: Houston Rockets, Prediction Correct: False, Contenders: {'Houston Rockets': 0.09779890810987457, 'Cleveland Cavaliers': 0.07215577635895139, 'Golden State Warriors': 0.06853608388317786, 'Philadelphia 76ers': 0.06314040741404803, 'Indiana Pacers': 0.061528813757135606}
# Year: 2019, Predicted Champion: Golden State Warriors, Prediction Correct: False, Contenders: {'Golden State Warriors': 0.08425575335316682, 'Milwaukee Bucks': 0.06792634421872401, 'Indiana Pacers': 0.06112451423232993, 'Portland Trail Blazers': 0.06104190117055548, 'Denver Nuggets': 0.060774468419577746}
# Year: 2020, Predicted Champion: Milwaukee Bucks, Prediction Correct: False, Contenders: {'Milwaukee Bucks': 0.21800240319205955, 'Los Angeles Lakers': 0.0678324507336822, 'Indiana Pacers': 0.05907573510887483, 'Houston Rockets': 0.056195845221865305, 'Philadelphia 76ers': 0.0507883490202831}
# Year: 2021, Predicted Champion: Utah Jazz, Prediction Correct: False, Contenders: {'Utah Jazz': 0.1299918695139617, 'Milwaukee Bucks': 0.06953335709971908, 'Miami Heat': 0.06781669279245765, 'Brooklyn Nets': 0.0673084383003351, 'Phoenix Suns': 0.060221336016471866}
# Year: 2022, Predicted Champion: Phoenix Suns, Prediction Correct: False, Contenders: {'Phoenix Suns': 0.1820288166879291, 'Golden State Warriors': 0.06438372790480684, 'Utah Jazz': 0.06279219381531433, 'Miami Heat': 0.059527133185376335, 'Memphis Grizzlies': 0.05814575092671586}
# Year: 2023, Predicted Champion: Milwaukee Bucks, Prediction Correct: False, Contenders: {'Milwaukee Bucks': 0.08302019115986796, 'Golden State Warriors': 0.06824283965382423, 'Boston Celtics': 0.06775614360983485, 'Cleveland Cavaliers': 0.06430442745373452, 'Denver Nuggets': 0.06317079432574371}
# Year: 2024, Predicted Champion: Boston Celtics, Prediction Correct: True, Contenders: {'Boston Celtics': 0.20126985254464277, 'Oklahoma City Thunder': 0.06896155195184206, 'Minnesota Timberwolves': 0.06354650778632417, 'Indiana Pacers': 0.06348215317324123, 'Denver Nuggets': 0.06327993904300813}
# Model Accuracy: 0.29545454545454547 (13/44) [Support Vector Machine]
#
#
# Year: 1981, Predicted Champion: Boston Celtics, Prediction Correct: True, Contenders: {'Boston Celtics': 0.09164530479751971, 'Philadelphia 76ers': 0.017218274217286268, 'Los Angeles Lakers': 0.0071223402490391855, 'Chicago Bulls': 0.00034366453042855165, 'Houston Rockets': 0.0001407399173819075}
# Year: 1982, Predicted Champion: San Antonio Spurs, Prediction Correct: False, Contenders: {'San Antonio Spurs': 0.9999643548973666, 'Atlanta Hawks': 3.766605446527113e-06, 'Washington Bullets': 3.766605446527113e-06, 'New Jersey Nets': 3.766605446527113e-06, 'Phoenix Suns': 3.766605446527113e-06}
# Year: 1983, Predicted Champion: Los Angeles Lakers, Prediction Correct: False, Contenders: {'Los Angeles Lakers': 0.9999643548973666, 'Atlanta Hawks': 3.766605446527126e-06, 'New York Knicks': 3.766605446527126e-06, 'Denver Nuggets': 3.766605446527126e-06, 'Portland Trail Blazers': 3.766605446527126e-06}
# Year: 1984, Predicted Champion: Los Angeles Lakers, Prediction Correct: False, Contenders: {'Philadelphia 76ers': 0.9999643548973666, 'Los Angeles Lakers': 0.9999643548973666, 'Washington Bullets': 3.766605446527126e-06, 'Kansas City Kings': 3.766605446527126e-06, 'Denver Nuggets': 3.766605446527126e-06}
# Year: 1985, Predicted Champion: Milwaukee Bucks, Prediction Correct: False, Contenders: {'Milwaukee Bucks': 0.2160281945357997, 'Philadelphia 76ers': 0.18808764017607213, 'Phoenix Suns': 3.5322128157840355e-06, 'Cleveland Cavaliers': 3.5322128157840355e-06, 'Chicago Bulls': 3.5322128157840355e-06}
# Year: 1986, Predicted Champion: Dallas Mavericks, Prediction Correct: False, Contenders: {'Dallas Mavericks': 0.11794626923030191, 'Los Angeles Lakers': 0.0004996668624250596, 'Boston Celtics': 2.5396832730312747e-05, 'Chicago Bulls': 3.3882941262153614e-06, 'San Antonio Spurs': 3.3882941262153614e-06}
# Year: 1987, Predicted Champion: Los Angeles Lakers, Prediction Correct: True, Contenders: {'Los Angeles Lakers': 0.9999632232632026, 'Boston Celtics': 1.171859021511961e-05, 'Denver Nuggets': 3.297678863350921e-06, 'Seattle SuperSonics': 3.297678863350921e-06, 'Chicago Bulls': 3.297678863350921e-06}
# Year: 1988, Predicted Champion: Los Angeles Lakers, Prediction Correct: True, Contenders: {'Los Angeles Lakers': 0.024071710788282574, 'San Antonio Spurs': 3.2306433726245744e-06, 'New York Knicks': 3.2306433726245744e-06, 'Washington Bullets': 3.2306433726245744e-06, 'Milwaukee Bucks': 3.2306433726245744e-06}
# Year: 1989, Predicted Champion: Detroit Pistons, Prediction Correct: True, Contenders: {'Portland Trail Blazers': 3.180359264149648e-06, 'Boston Celtics': 3.180359264149648e-06, 'Golden State Warriors': 3.180359264149648e-06, 'Denver Nuggets': 3.180359264149648e-06, 'Houston Rockets': 3.180359264149648e-06}
# Year: 1990, Predicted Champion: Los Angeles Lakers, Prediction Correct: False, Contenders: {'Los Angeles Lakers': 0.006225311308375291, 'Houston Rockets': 3.1407224507396116e-06, 'Indiana Pacers': 3.1407224507396116e-06, 'Denver Nuggets': 3.1407224507396116e-06, 'Milwaukee Bucks': 3.1407224507396116e-06}
# Year: 1991, Predicted Champion: Portland Trail Blazers, Prediction Correct: False, Contenders: {'Portland Trail Blazers': 0.026939602770028305, 'Chicago Bulls': 0.0012433114091984971, 'Detroit Pistons': 0.00010229801645019887, 'Boston Celtics': 2.0445643867548936e-05, 'New York Knicks': 1.8991676570359878e-05}
# Year: 1992, Predicted Champion: Chicago Bulls, Prediction Correct: True, Contenders: {'Chicago Bulls': 0.9972130175654474, 'Cleveland Cavaliers': 7.709251952032174e-05, 'Miami Heat': 6.378372389166786e-05, 'New Jersey Nets': 6.378372389166786e-05, 'Indiana Pacers': 6.378372389166786e-05}
# Year: 1993, Predicted Champion: Phoenix Suns, Prediction Correct: False, Contenders: {'Phoenix Suns': 0.05367228372726285, 'Chicago Bulls': 0.02045457690740097, 'New York Knicks': 0.0031742089713871517, 'Cleveland Cavaliers': 0.0002073764862940704, 'Seattle SuperSonics': 9.327942478387974e-05}
# Year: 1994, Predicted Champion: Seattle SuperSonics, Prediction Correct: False, Contenders: {'Seattle SuperSonics': 0.9242149036370612, 'Chicago Bulls': 0.00017959212449453186, 'Phoenix Suns': 7.534435430139741e-05, 'Houston Rockets': 7.534435430139741e-05, 'Utah Jazz': 6.810987715157462e-05}
# Year: 1995, Predicted Champion: Phoenix Suns, Prediction Correct: False, Contenders: {'Phoenix Suns': 0.01586142847112054, 'San Antonio Spurs': 0.00665561039154727, 'Utah Jazz': 0.0016284739835586439, 'New York Knicks': 0.00043682694769288345, 'Atlanta Hawks': 0.0002711748448254743}
# Year: 1996, Predicted Champion: Chicago Bulls, Prediction Correct: True, Contenders: {'Chicago Bulls': 0.999696434653813, 'Orlando Magic': 0.01838763078214822, 'Houston Rockets': 0.00877152725790726, 'Seattle SuperSonics': 0.0010646945963788347, 'San Antonio Spurs': 0.0006255202017782879}
# Year: 1997, Predicted Champion: Chicago Bulls, Prediction Correct: True, Contenders: {'Chicago Bulls': 0.9985898567225738, 'Utah Jazz': 0.002975333249013204, 'Miami Heat': 0.001279272582905828, 'Houston Rockets': 0.0007155976908712769, 'New York Knicks': 0.000274136553494312}
# Year: 1998, Predicted Champion: Chicago Bulls, Prediction Correct: True, Contenders: {'Chicago Bulls': 0.984551815258062, 'Houston Rockets': 0.014744830144122395, 'Seattle SuperSonics': 0.01128031414540673, 'Utah Jazz': 0.001527200943845825, 'Phoenix Suns': 0.0003836930571625245}
# Year: 1999, Predicted Champion: San Antonio Spurs, Prediction Correct: True, Contenders: {'San Antonio Spurs': 0.0636052251452445, 'Utah Jazz': 0.04693617934651973, 'Houston Rockets': 0.0005193046268738923, 'Sacramento Kings': 0.00025729426115740753, 'Miami Heat': 0.0002493938757281019}
# Year: 2000, Predicted Champion: Los Angeles Lakers, Prediction Correct: True, Contenders: {'Los Angeles Lakers': 0.9891600257777028, 'San Antonio Spurs': 0.0025487801052001143, 'Indiana Pacers': 0.0008841901885197072, 'Seattle SuperSonics': 0.0006005330273234334, 'New York Knicks': 0.00025052240433535603}
# Year: 2001, Predicted Champion: San Antonio Spurs, Prediction Correct: False, Contenders: {'San Antonio Spurs': 0.1755339576756067, 'Los Angeles Lakers': 0.01263953458418102, 'Minnesota Timberwolves': 0.001828569159349748, 'Sacramento Kings': 0.0004753439489031028, 'Milwaukee Bucks': 0.0003618846617376651}
# Year: 2002, Predicted Champion: Sacramento Kings, Prediction Correct: False, Contenders: {'Sacramento Kings': 0.6966749065543902, 'Boston Celtics': 0.6518369226783132, 'Los Angeles Lakers': 0.11805029005397838, 'Orlando Magic': 0.006120465017399183, 'Toronto Raptors': 0.00029814421529004385}
# Year: 2003, Predicted Champion: Los Angeles Lakers, Prediction Correct: False, Contenders: {'Los Angeles Lakers': 0.47605844481313014, 'Sacramento Kings': 0.4613171363161061, 'San Antonio Spurs': 0.025596474259816548, 'Boston Celtics': 0.018394749337855728, 'Dallas Mavericks': 0.0014466016484005824}
# Year: 2004, Predicted Champion: San Antonio Spurs, Prediction Correct: False, Contenders: {'San Antonio Spurs': 0.05712634803384924, 'Los Angeles Lakers': 0.005671570129765805, 'Minnesota Timberwolves': 0.0017007109789682227, 'New Jersey Nets': 0.0007636085597813077, 'Dallas Mavericks': 0.0003591465852081083}
# Year: 2005, Predicted Champion: Phoenix Suns, Prediction Correct: False, Contenders: {'Phoenix Suns': 0.46772721464328876, 'San Antonio Spurs': 0.03889941352434277, 'Detroit Pistons': 0.025809843646855842, 'Miami Heat': 0.022770433989885413, 'Memphis Grizzlies': 0.001199496415478423}
# Year: 2006, Predicted Champion: Detroit Pistons, Prediction Correct: False, Contenders: {'Detroit Pistons': 0.9705776473758383, 'San Antonio Spurs': 0.8228441138250461, 'Phoenix Suns': 0.29351087759477773, 'Dallas Mavericks': 0.0020217580319733665, 'Indiana Pacers': 0.0011244213221556095}
# Year: 2007, Predicted Champion: Dallas Mavericks, Prediction Correct: False, Contenders: {'Dallas Mavericks': 0.18485330654620105, 'San Antonio Spurs': 0.038139440907338604, 'Phoenix Suns': 0.012327704837079808, 'Miami Heat': 0.010773963701314107, 'Detroit Pistons': 0.0032181181951128866}
# Year: 2008, Predicted Champion: Boston Celtics, Prediction Correct: True, Contenders: {'Boston Celtics': 0.3327446582104029, 'Los Angeles Lakers': 0.01952941949278749, 'San Antonio Spurs': 0.010427562435926881, 'Phoenix Suns': 0.008249850930287527, 'Dallas Mavericks': 0.0047887328560777395}
# Year: 2009, Predicted Champion: Cleveland Cavaliers, Prediction Correct: False, Contenders: {'Cleveland Cavaliers': 0.7600599408902665, 'Los Angeles Lakers': 0.38891372926719314, 'San Antonio Spurs': 0.008695885170080107, 'Boston Celtics': 0.003501772021855674, 'Houston Rockets': 0.003352897207704446}
# Year: 2010, Predicted Champion: Cleveland Cavaliers, Prediction Correct: False, Contenders: {'Cleveland Cavaliers': 0.15895893618244317, 'Los Angeles Lakers': 0.1451450400129976, 'Orlando Magic': 0.049136408961637144, 'Charlotte Bobcats': 0.0044133193429402775, 'Dallas Mavericks': 0.0025862805619512}
# Year: 2011, Predicted Champion: Los Angeles Lakers, Prediction Correct: False, Contenders: {'Los Angeles Lakers': 0.6396555978980373, 'Boston Celtics': 0.01563122425073616, 'Miami Heat': 0.012100154859994557, 'San Antonio Spurs': 0.009106915769092254, 'Chicago Bulls': 0.005818753126433132}
# Year: 2012, Predicted Champion: Miami Heat, Prediction Correct: True, Contenders: {'Miami Heat': 0.7526167855504083, 'Chicago Bulls': 0.10381551308004175, 'San Antonio Spurs': 0.0266101423777949, 'Oklahoma City Thunder': 0.008123181717829551, 'Los Angeles Lakers': 0.005160455164893178}
# Year: 2013, Predicted Champion: Miami Heat, Prediction Correct: True, Contenders: {'Miami Heat': 0.5816354087489216, 'Denver Nuggets': 0.21164849055272886, 'Oklahoma City Thunder': 0.11645614268084106, 'San Antonio Spurs': 0.0041498460364423635, 'Los Angeles Lakers': 0.0027636863536224876}
# Year: 2014, Predicted Champion: Miami Heat, Prediction Correct: False, Contenders: {'Miami Heat': 0.7264631763280927, 'San Antonio Spurs': 0.017077883660520876, 'Indiana Pacers': 0.012534032935926103, 'Oklahoma City Thunder': 0.003377724768596144, 'Charlotte Bobcats': 0.0020043685830730905}
# Year: 2015, Predicted Champion: Golden State Warriors, Prediction Correct: True, Contenders: {'Golden State Warriors': 0.9408271810780128, 'Atlanta Hawks': 0.7101292477513467, 'Cleveland Cavaliers': 0.020558012939804523, 'San Antonio Spurs': 0.008201803788819361, 'Portland Trail Blazers': 0.004357754975328582}
# Year: 2016, Predicted Champion: Golden State Warriors, Prediction Correct: False, Contenders: {'Golden State Warriors': 0.9951832894899052, 'Cleveland Cavaliers': 0.020276294957169042, 'San Antonio Spurs': 0.013156646873901199, 'Los Angeles Clippers': 0.0017145344016886773, 'Atlanta Hawks': 0.0016658996353453167}
# Year: 2017, Predicted Champion: Golden State Warriors, Prediction Correct: True, Contenders: {'Golden State Warriors': 0.970353032236022, 'Cleveland Cavaliers': 0.022200001984305176, 'Atlanta Hawks': 0.002004559331980765, 'Chicago Bulls': 0.0016466921162515678, 'Portland Trail Blazers': 0.0014523370120826018}
# Year: 2018, Predicted Champion: Golden State Warriors, Prediction Correct: True, Contenders: {'Golden State Warriors': 0.300913679943642, 'Houston Rockets': 0.13737361144896326, 'Portland Trail Blazers': 0.0015205819440486724, 'Boston Celtics': 0.0014511096906664979, 'Toronto Raptors': 0.0014318886961591796}
# ...
# Year: 2015, Predicted Champion: Golden State Warriors, Prediction Correct: True, Contenders: {'Golden State Warriors': 0.9999998826606296, 'San Antonio Spurs': 0.9998493754730912, 'Atlanta Hawks': 0.311603278852507, 'Cleveland Cavaliers': 0.03427965389713247, 'Los Angeles Clippers': 0.00863964554195321}
# Year: 2016, Predicted Champion: Golden State Warriors, Prediction Correct: False, Contenders: {'Golden State Warriors': 1.0, 'San Antonio Spurs': 0.9987861862017886, 'Cleveland Cavaliers': 0.8653493384648527, 'Oklahoma City Thunder': 0.000790738347030142, 'Toronto Raptors': 9.836980636283738e-07}
# Year: 2017, Predicted Champion: Golden State Warriors, Prediction Correct: True, Contenders: {'Golden State Warriors': 0.9999999999999858, 'San Antonio Spurs': 0.3983798489311927, 'Cleveland Cavaliers': 1.4942042799203064e-05, 'Houston Rockets': 7.804315848061383e-07, 'Utah Jazz': 6.495189088429236e-08}
# Year: 2018, Predicted Champion: Golden State Warriors, Prediction Correct: True, Contenders: {'Golden State Warriors': 0.999999986076594, 'Houston Rockets': 0.9998426109616813, 'Toronto Raptors': 0.4751837946889801, 'Boston Celtics': 1.2196602954750772e-05, 'Philadelphia 76ers': 7.604392110729625e-07}
# Year: 2019, Predicted Champion: Golden State Warriors, Prediction Correct: False, Contenders: {'Golden State Warriors': 0.9999999999997828, 'Milwaukee Bucks': 0.9977027141150109, 'Toronto Raptors': 0.311171340764298, 'Houston Rockets': 0.0171645701135054, 'Boston Celtics': 0.0005727403457471223}
# Year: 2020, Predicted Champion: Milwaukee Bucks, Prediction Correct: False, Contenders: {'Milwaukee Bucks': 0.9999849157511675, 'Toronto Raptors': 0.989886380227163, 'Los Angeles Clippers': 0.48705876665042586, 'Los Angeles Lakers': 0.4576864583560234, 'Boston Celtics': 0.0014808220388261438}
# Year: 2021, Predicted Champion: Utah Jazz, Prediction Correct: False, Contenders: {'Utah Jazz': 0.9908361471657375, 'Brooklyn Nets': 0.09223815422408221, 'Los Angeles Clippers': 0.06737031115638922, 'Phoenix Suns': 0.05001700879854032, 'Milwaukee Bucks': 0.02352397432571483}
# Year: 2022, Predicted Champion: Phoenix Suns, Prediction Correct: False, Contenders: {'Phoenix Suns': 0.9999999191765933, 'Milwaukee Bucks': 0.2637224821633579, 'Boston Celtics': 0.1980667088175545, 'Golden State Warriors': 0.013204182192072518, 'Utah Jazz': 0.012489898702175602}
# Year: 2023, Predicted Champion: Boston Celtics, Prediction Correct: False, Contenders: {'Boston Celtics': 0.9999929455080178, 'Milwaukee Bucks': 0.8579307695614679, 'Denver Nuggets': 0.02132928101758555, 'Philadelphia 76ers': 0.006659837883768991, 'Cleveland Cavaliers': 0.0009826122332959278}
# Year: 2024, Predicted Champion: Boston Celtics, Prediction Correct: True, Contenders: {'Boston Celtics': 0.9999999936922492, 'Denver Nuggets': 0.9912507831946991, 'Oklahoma City Thunder': 0.14986855103594487, 'Minnesota Timberwolves': 0.009317190862741073, 'New Orleans Pelicans': 7.923612762752844e-07}
# Model Accuracy: 0.45454545454545453 (20/44) [Naive Bayes]
#
#
# Year: 1981, Predicted Champion: Boston Celtics, Prediction Correct: True, Contenders: {'Boston Celtics': 0.8807970779778823, 'Houston Rockets': 0.11920292202211755, 'Kansas City Kings': 0.11920292202211755, 'Indiana Pacers': 0.11920292202211755, 'Portland Trail Blazers': 0.11920292202211755}
# Year: 1982, Predicted Champion: San Antonio Spurs, Prediction Correct: False, Contenders: {'San Antonio Spurs': 0.8807970779778823, 'Atlanta Hawks': 0.11920292202211755, 'Washington Bullets': 0.11920292202211755, 'New Jersey Nets': 0.11920292202211755, 'Phoenix Suns': 0.11920292202211755}
# Year: 1983, Predicted Champion: Los Angeles Lakers, Prediction Correct: False, Contenders: {'Los Angeles Lakers': 0.5931233481237943, 'Philadelphia 76ers': 0.5198588845295998, 'Boston Celtics': 0.3511724261035122, 'Atlanta Hawks': 0.22836530862425264, 'Denver Nuggets': 0.18632650948050677}
# Year: 1984, Predicted Champion: Los Angeles Lakers, Prediction Correct: False, Contenders: {'Los Angeles Lakers': 0.6504159848619206, 'Philadelphia 76ers': 0.4450583938275488, 'Boston Celtics': 0.37612561334295613, 'Detroit Pistons': 0.31630161180585703, 'Utah Jazz': 0.29825634782786037}
# Year: 1985, Predicted Champion: Boston Celtics, Prediction Correct: False, Contenders: {'Boston Celtics': 0.510403734091749, 'Los Angeles Lakers': 0.42915934220954216, 'Milwaukee Bucks': 0.355453329842796, 'Philadelphia 76ers': 0.3396298230590363, 'Chicago Bulls': 0.2716791521580567}
# Year: 1986, Predicted Champion: Boston Celtics, Prediction Correct: True, Contenders: {'Boston Celtics': 0.5548852040997905, 'Los Angeles Lakers': 0.47605139964920196, 'Washington Bullets': 0.3810591174546327, 'Dallas Mavericks': 0.3206681509184915, 'Chicago Bulls': 0.3006060355891404}
# Year: 1987, Predicted Champion: Los Angeles Lakers, Prediction Correct: True, Contenders: {'Los Angeles Lakers': 0.5396590494323588, 'Boston Celtics': 0.5342236206698345, 'Atlanta Hawks': 0.35613054077883616, 'Detroit Pistons': 0.3187417919472595, 'Philadelphia 76ers': 0.28835057352562554}
# Year: 1988, Predicted Champion: Los Angeles Lakers, Prediction Correct: True, Contenders: {'Los Angeles Lakers': 0.3917057196621054, 'Dallas Mavericks': 0.34212898577847595, 'Denver Nuggets': 0.339311023242827, 'New York Knicks': 0.32642270341784124, 'Chicago Bulls': 0.3259688833512475}
# Year: 1989, Predicted Champion: Detroit Pistons, Prediction Correct: True, Contenders: {'Detroit Pistons': 0.4322759146650967, 'New York Knicks': 0.32838320675968297, 'Utah Jazz': 0.31632241525229043, 'Cleveland Cavaliers': 0.2958133708320584, 'Phoenix Suns': 0.2635772217891931}
# Year: 1990, Predicted Champion: Los Angeles Lakers, Prediction Correct: False, Contenders: {'Los Angeles Lakers': 0.6375430593161422, 'Portland Trail Blazers': 0.3750201498972628, 'Philadelphia 76ers': 0.3680040185805008, 'San Antonio Spurs': 0.35807928043641163, 'Phoenix Suns': 0.31781109795783813}
# Year: 1991, Predicted Champion: Portland Trail Blazers, Prediction Correct: False, Contenders: {'Portland Trail Blazers': 0.4960302016583113, 'Los Angeles Lakers': 0.41401732938047364, 'San Antonio Spurs': 0.4067659932385212, 'Boston Celtics': 0.39461989305527745, 'Chicago Bulls': 0.35493572805324985}
# Year: 1992, Predicted Champion: Chicago Bulls, Prediction Correct: True, Contenders: {'Chicago Bulls': 0.6707176876570828, 'Boston Celtics': 0.37652577096606715, 'Phoenix Suns': 0.3464015278543664, 'Utah Jazz': 0.3464015278543664, 'Cleveland Cavaliers': 0.3259525083205589}
# Year: 1993, Predicted Champion: Phoenix Suns, Prediction Correct: False, Contenders: {'Phoenix Suns': 0.4196383022377872, 'Chicago Bulls': 0.40454534468178394, 'New York Knicks': 0.39311283594305374, 'Cleveland Cavaliers': 0.3728150466353179, 'Seattle SuperSonics': 0.33063834795470287}
# Year: 1994, Predicted Champion: Seattle SuperSonics, Prediction Correct: False, Contenders: {'Seattle SuperSonics': 0.5246743861067346, 'Chicago Bulls': 0.38919488437757743, 'Utah Jazz': 0.31825436934632934, 'New York Knicks': 0.317125118169403, 'Atlanta Hawks': 0.30649818788929434}
# Year: 1995, Predicted Champion: Utah Jazz, Prediction Correct: False, Contenders: {'Utah Jazz': 0.4051323585707144, 'Phoenix Suns': 0.39164684533919863, 'Charlotte Hornets': 0.3783892148808611, 'Seattle SuperSonics': 0.3679911154581381, 'San Antonio Spurs': 0.3627229651484146}
# Year: 1996, Predicted Champion: Chicago Bulls, Prediction Correct: True, Contenders: {'Chicago Bulls': 0.6105983556102926, 'San Antonio Spurs': 0.48401149300639335, 'Miami Heat': 0.4278390624103274, 'Los Angeles Lakers': 0.4228669676861602, 'Houston Rockets': 0.4224250415587142}
# Year: 1997, Predicted Champion: Chicago Bulls, Prediction Correct: True, Contenders: {'Chicago Bulls': 0.7181296418388622, 'Houston Rockets': 0.4817712898438567, 'Miami Heat': 0.4676887581392798, 'Utah Jazz': 0.39368537461696057, 'New York Knicks': 0.38285168408810916}
# Year: 1998, Predicted Champion: Chicago Bulls, Prediction Correct: True, Contenders: {'Chicago Bulls': 0.5887425236398999, 'Seattle SuperSonics': 0.45564462374647435, 'Phoenix Suns': 0.45215177795817824, 'Los Angeles Lakers': 0.4161628411922634, 'Indiana Pacers': 0.38877025603222304}
# Year: 1999, Predicted Champion: San Antonio Spurs, Prediction Correct: True, Contenders: {'San Antonio Spurs': 0.4830089372288822, 'Utah Jazz': 0.44964339731164676, 'Portland Trail Blazers': 0.3840243323786057, 'Miami Heat': 0.3776240803268488, 'Orlando Magic': 0.37314815368694076}
# Year: 2000, Predicted Champion: Los Angeles Lakers, Prediction Correct: True, Contenders: {'Los Angeles Lakers': 0.5733714092912955, 'Sacramento Kings': 0.4165206395247233, 'Miami Heat': 0.4037498162323991, 'Phoenix Suns': 0.38725560136319725, 'Portland Trail Blazers': 0.3746547930207135}
# Year: 2001, Predicted Champion: San Antonio Spurs, Prediction Correct: False, Contenders: {'San Antonio Spurs': 0.5139972912944945, 'Portland Trail Blazers': 0.3757308559150689, 'Sacramento Kings': 0.3671664176067434, 'New York Knicks': 0.3664296929747762, 'Philadelphia 76ers': 0.3534702359039388}
# Year: 2002, Predicted Champion: Los Angeles Lakers, Prediction Correct: True, Contenders: {'Los Angeles Lakers': 0.5774816042396355, 'Sacramento Kings': 0.48912555725307444, 'Orlando Magic': 0.39086440416447915, 'Boston Celtics': 0.36146969030222964, 'Minnesota Timberwolves': 0.34874331054179114}
# Year: 2003, Predicted Champion: Sacramento Kings, Prediction Correct: False, Contenders: {'Sacramento Kings': 0.4629819153496197, 'San Antonio Spurs': 0.42765033353782533, 'Los Angeles Lakers': 0.4195243910901146, 'Portland Trail Blazers': 0.3755436754631149, 'New Orleans Hornets': 0.36666195677298813}
# Year: 2004, Predicted Champion: San Antonio Spurs, Prediction Correct: False, Contenders: {'San Antonio Spurs': 0.41991059846580986, 'Minnesota Timberwolves': 0.4167409087764507, 'Dallas Mavericks': 0.3526650023843274, 'Detroit Pistons': 0.35147483774353316, 'Houston Rockets': 0.33343226910993495}
# Year: 2005, Predicted Champion: San Antonio Spurs, Prediction Correct: True, Contenders: {'San Antonio Spurs': 0.4591407880055565, 'Detroit Pistons': 0.41076710206816835, 'Miami Heat': 0.3403538304178707, 'Phoenix Suns': 0.3159482497491768, 'Memphis Grizzlies': 0.30297857453008115}
# Year: 2006, Predicted Champion: Detroit Pistons, Prediction Correct: False, Contenders: {'Detroit Pistons': 0.5962462831285176, 'San Antonio Spurs': 0.5132463691263051, 'Phoenix Suns': 0.43422147896879104, 'Indiana Pacers': 0.3539451919743335, 'Dallas Mavericks': 0.3500072543141046}
# Year: 2007, Predicted Champion: Dallas Mavericks, Prediction Correct: False, Contenders: {'Dallas Mavericks': 0.5027594124654868, 'Phoenix Suns': 0.42189583809996856, 'San Antonio Spurs': 0.38820898181185326, 'Chicago Bulls': 0.3695000936972991, 'Detroit Pistons': 0.3475112645360548}
# Year: 2008, Predicted Champion: Boston Celtics, Prediction Correct: True, Contenders: {'Boston Celtics': 0.4857023142748272, 'San Antonio Spurs': 0.4076725735641398, 'Phoenix Suns': 0.3757921280907728, 'Los Angeles Lakers': 0.36687581377465056, 'Utah Jazz': 0.3449887642062003}
# Year: 2009, Predicted Champion: Cleveland Cavaliers, Prediction Correct: False, Contenders: {'Cleveland Cavaliers': 0.5800374517924841, 'Boston Celtics': 0.49908025099559217, 'Los Angeles Lakers': 0.48394522289233255, 'Orlando Magic': 0.40079945656079896, 'Houston Rockets': 0.34034532388072003}
# Year: 2010, Predicted Champion: Orlando Magic, Prediction Correct: False, Contenders: {'Orlando Magic': 0.5160763854767824, 'Cleveland Cavaliers': 0.5056131642161582, 'Los Angeles Lakers': 0.44816702097735467, 'Utah Jazz': 0.392926000414204, 'San Antonio Spurs': 0.361896812370843}
# Year: 2011, Predicted Champion: Boston Celtics, Prediction Correct: False, Contenders: {'Boston Celtics': 0.5225110238028541, 'Los Angeles Lakers': 0.4773069576137543, 'San Antonio Spurs': 0.444461152678738, 'Orlando Magic': 0.44055005094506866, 'Miami Heat': 0.38963278041403204}
# Year: 2012, Predicted Champion: Miami Heat, Prediction Correct: True, Contenders: {'Miami Heat': 0.5204030319210751, 'Chicago Bulls': 0.4657829441356432, 'San Antonio Spurs': 0.46370168775300735, 'Oklahoma City Thunder': 0.384812154701381, 'Dallas Mavericks': 0.3597225281359681}
# Year: 2013, Predicted Champion: Miami Heat, Prediction Correct: True, Contenders: {'Miami Heat': 0.5218985538703973, 'San Antonio Spurs': 0.4474714176048408, 'Oklahoma City Thunder': 0.4374741132039551, 'Los Angeles Clippers': 0.4209931510503863, 'Indiana Pacers': 0.3591855569479009}
# Year: 2014, Predicted Champion: Miami Heat, Prediction Correct: False, Contenders: {'Miami Heat': 0.5311796609738746, 'San Antonio Spurs': 0.479742957123281, 'Indiana Pacers': 0.41704390237379035, 'Houston Rockets': 0.38018416523933246, 'Oklahoma City Thunder': 0.362409558219013}
# Year: 2015, Predicted Champion: Golden State Warriors, Prediction Correct: True, Contenders: {'Golden State Warriors': 0.48798359184536405, 'Cleveland Cavaliers': 0.47708365263090474, 'Atlanta Hawks': 0.47439746687026624, 'San Antonio Spurs': 0.45216704942233893, 'Los Angeles Clippers': 0.3877213646821688}
# Year: 2016, Predicted Champion: Golden State Warriors, Prediction Correct: False, Contenders: {'Golden State Warriors': 0.5998663360549187, 'San Antonio Spurs': 0.4332536071937497, 'Cleveland Cavaliers': 0.3992775459609799, 'Oklahoma City Thunder': 0.35895397491028375, 'Atlanta Hawks': 0.3549468209852812}
# Year: 2017, Predicted Champion: Golden State Warriors, Prediction Correct: True, Contenders: {'Golden State Warriors': 0.5049929552058765, 'Cleveland Cavaliers': 0.4056742225719823, 'San Antonio Spurs': 0.3065137057457732, 'Chicago Bulls': 0.30456542397329545, 'Los Angeles Clippers': 0.28465276652674576}
# Year: 2018, Predicted Champion: Golden State Warriors, Prediction Correct: True, Contenders: {'Golden State Warriors': 0.5069785518356107, 'Houston Rockets': 0.48546881401722214, 'Philadelphia 76ers': 0.3567359479744739, 'Utah Jazz': 0.32906962909830856, 'Toronto Raptors': 0.3218278385852635}
# Year: 2019, Predicted Champion: Milwaukee Bucks, Prediction Correct: False, Contenders: {'Milwaukee Bucks': 0.5120472336593637, 'Golden State Warriors': 0.5113841476489623, 'Toronto Raptors': 0.41627674776684764, 'Utah Jazz': 0.3981636984652395, 'Boston Celtics': 0.3968573846646439}
# Year: 2020, Predicted Champion: Milwaukee Bucks, Prediction Correct: False, Contenders: {'Milwaukee Bucks': 0.4736903372810171, 'Los Angeles Lakers': 0.45333509216929696, 'Los Angeles Clippers': 0.40979377748526474, 'Toronto Raptors': 0.39378963086258345, 'Boston Celtics': 0.33032085616184026}
# Year: 2021, Predicted Champion: Los Angeles Lakers, Prediction Correct: False, Contenders: {'Los Angeles Lakers': 0.4434730483960551, 'Utah Jazz': 0.4038099139273729, 'Miami Heat': 0.3828030972291516, 'Philadelphia 76ers': 0.3723314597505859, 'Milwaukee Bucks': 0.36615274124874714}
# Year: 2022, Predicted Champion: Phoenix Suns, Prediction Correct: False, Contenders: {'Phoenix Suns': 0.5296452881059787, 'Boston Celtics': 0.4122631989336158, 'Milwaukee Bucks': 0.3875936260845676, 'Golden State Warriors': 0.3753188513211767, 'Memphis Grizzlies': 0.3699870560939899}
# Year: 2023, Predicted Champion: Milwaukee Bucks, Prediction Correct: False, Contenders: {'Milwaukee Bucks': 0.5853990065354628, 'Boston Celtics': 0.5300686589353739, 'Golden State Warriors': 0.4860562469152628, 'Denver Nuggets': 0.41409949662990636, 'Memphis Grizzlies': 0.3764166652431106}
# Year: 2024, Predicted Champion: Boston Celtics, Prediction Correct: True, Contenders: {'Boston Celtics': 0.5462123482619007, 'Denver Nuggets': 0.505040033718058, 'Cleveland Cavaliers': 0.334428867385204, 'New Orleans Pelicans': 0.3186284987250407, 'Minnesota Timberwolves': 0.30716428544980695}
# Model Accuracy: 0.45454545454545453 (20/44) [AdaBoost]
